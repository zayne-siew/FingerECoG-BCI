# %% [markdown]
# # CAE-LSTM Hybrid Model (Training)
#
# **Authors:** KHOO Jing Heng, Zayne SIEW
#
# **Version:** 1.0 (05/04/2025)
#
# ### About this notebook
#
# This notebook implements a CAE-LSTM model for training on the ECoG data.
#
# ### Requirements
#
# - Python 3
# - Matplotlib
# - Numpy
# - Scipy
# - Torch

# %% [markdown]
# ## 0. Imports and Torch-CUDA Config

# %%
from itertools import product

import matplotlib.pyplot as plt
import numpy as np

import torch
import torch.nn.functional as F
from torch.utils.data import DataLoader

from constants import (
    SUBJECT_ID,
    CHANNELS_NUM,
    ECOG_TRAIN_FILEPATH,
    ECOG_VAL_FILEPATH,
    FLEXION_TRAIN_FILEPATH,
    FLEXION_VAL_FILEPATH,
    WAVELET_NUM,
)
from data import EcogDataset, plot_ecog_data
from eval import cosine_correlation_metric, pearson_correlation_metric, test_model
from model import EncoderDecoder

# %%
# For windows/linux will try CUDA first, then CPU
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(DEVICE)

# Set default device for following code, so we don't need to specify device every time
torch.set_default_device(DEVICE)
# Out:
# cuda

# %% [markdown]
# ## 1. Data Loading and Visualisation

# %%
# Define directory where data is stored
DATA_DIR = "../data"

finger_flex_cropped: np.ndarray = np.load(f'{DATA_DIR}/{FLEXION_TRAIN_FILEPATH}')
X_spectrogram_cropped: np.ndarray = np.load(f'{DATA_DIR}/{ECOG_TRAIN_FILEPATH}')

finger_flex_cropped_val: np.ndarray = np.load(f'{DATA_DIR}/{FLEXION_VAL_FILEPATH}')
X_spectrogram_cropped_val: np.ndarray = np.load(f'{DATA_DIR}/{ECOG_VAL_FILEPATH}')

# %%
train_dataset = EcogDataset(X_spectrogram_cropped, finger_flex_cropped)
print(X_spectrogram_cropped.shape, finger_flex_cropped.shape)
print(len(train_dataset))

val_dataset = EcogDataset(X_spectrogram_cropped_val, finger_flex_cropped_val)
print(X_spectrogram_cropped_val.shape, finger_flex_cropped_val.shape)
print(len(val_dataset))
# Out:
# (48, 40, 39980) (5, 39980)
# 39724
# (48, 40, 19980) (5, 19980)
# 19724

# %%
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True, generator=torch.Generator(device='cuda'))
val_loader = DataLoader(val_dataset, batch_size=128, shuffle=False, generator=torch.Generator(device='cuda'))

# %%
# Call the visualization function
plot_ecog_data(train_dataset)
# Out:
# Input (x) Data Statistics:
# Shape: (48, 40, 256)
# Mean: 26.572364807128906
# Std: 96.56010437011719
# Min: -78.4576416015625
# Max: 1655.322021484375
#
# Target (y) Data Statistics:
# Shape: (5, 256)
# Mean: 0.16989579796791077
# Std: 0.04146142676472664
# Min: 0.09741489589214325
# Max: 0.2235344499349594

# %% [markdown]
# ## 2. Model Training
#
# This section trains a new `EncoderDecoder` model.

# %%
def train(
    model: EncoderDecoder,
    train_loader: DataLoader,
    val_loader: DataLoader,
    num_epochs: int = 100,
    lr: float = 1e-3,
    device: torch.device = DEVICE,
    alpha: float = 0.5,
    weight_decay: float = 1e-4,
) -> EncoderDecoder:
    """Trains an instance of an `EncoderDecoder` model.

    This function also outputs evaluation metrics on the validation set while training.

    Parameters:
        model (EncoderDecoder):
            The `EncoderDecoder` model instance to train.
        train_lodaer (DataLoader):
            Dataloader of the training dataset.
        val_loader (DataLoader):
            Dataloader of the validation dataset.
        num_epochs (int, default=100):
            Number of epochs to train the model on.
        lr (float, default=1e-3):
            Learning rate of the `AdamW` optimiser.
        device (torch.device, default=DEVICE):
            Desired torch device to use for computation.
        alpha (float, default=0.5):
            Weightage in loss function between MSE loss and cosine similarity.
        weight_decay (float, default=1e-4):
            Weight decay for the `AdamW` optimiser.

    Returns:
        EncoderDecoder:
            The trained model.
    """

    model.to(device)
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)

    train_losses, val_losses = [], []
    train_corrs, val_corrs = [], []
    pearson_losses = []

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        train_corr = 0.0

        for batch in train_loader:
            x, y = batch
            x, y = x.to(device), y.to(device)

            optimizer.zero_grad()
            pred = model(x)

            mse_loss = F.mse_loss(pred, y)
            corr = cosine_correlation_metric(pred, y)
            final_loss = alpha*mse_loss + alpha*(1. - corr)

            final_loss.backward()
            optimizer.step()

            train_loss += final_loss.item()
            train_corr += corr.item()

        train_loss /= len(train_loader)
        train_corr /= len(train_loader)
        train_losses.append(train_loss)
        train_corrs.append(train_corr)

        print(f"Epoch {epoch+1}/{num_epochs} - Train Loss: {train_loss:.4f}, Train Corr: {train_corr:.4f}")

        model.eval()
        val_loss = 0.0
        val_corr = 0.0
        pearson_loss_sum = 0.0
        with torch.no_grad():
            for batch in val_loader:
                x, y = batch
                x, y = x.to(device), y.to(device)

                pred = model(x)

                mse_loss = F.mse_loss(pred, y)
                corr = cosine_correlation_metric(pred, y)
                final_loss = alpha*mse_loss + alpha*(1. - corr)

                pearson_loss_metric = pearson_correlation_metric(pred, y)

                val_loss += final_loss.item()
                val_corr += corr.item()
                pearson_loss_sum += pearson_loss_metric.item()

        val_loss /= len(val_loader)
        val_corr /= len(val_loader)
        pearson_loss_sum /= len(val_loader)

        val_losses.append(val_loss)
        val_corrs.append(val_corr)
        pearson_losses.append(pearson_loss_sum)

        print(f"Epoch {epoch+1}/{num_epochs} - Val Loss: {val_loss:.4f}, Val Corr: {val_corr:.4f}, Pearson Corr: {pearson_loss_sum:.4f}")

    # Plot training and validation loss
    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.plot(range(1, num_epochs + 1), train_losses, label='Train Loss', marker='o')
    plt.plot(range(1, num_epochs + 1), val_losses, label='Val Loss', marker='o')
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.title("Training and Validation Loss")

    # Plot correlation metrics
    plt.subplot(1, 2, 2)
    plt.plot(range(1, num_epochs + 1), train_corrs, label='Train Corr', marker='o')
    plt.plot(range(1, num_epochs + 1), val_corrs, label='Val Corr', marker='o')
    plt.plot(range(1, num_epochs + 1), pearson_losses, label='Pearson Corr', marker='o')
    plt.xlabel("Epoch")
    plt.ylabel("Correlation")
    plt.legend()
    plt.title("Training, Validation, Pearson Correlation")

    plt.tight_layout()
    plt.show()

    return model

# %%
# model = EncoderDecoder(input_channels=CHANNELS_NUM * WAVELET_NUM, output_channels=5)
# model = train(model, train_loader, val_loader, num_epochs=50)

# %% [markdown]
# ### 2.1 GridSearchCV Hyperparameter Tuning
#
# We tune on the learning rate, alpha, and weight decay.

# %%
param_grid = {
    'lr': [5e-3],
    'alpha': [0.3],
    'weight_decay': [1e-4],
    'num_epochs': [50]
}

param_combinations = list(product(*param_grid.values()))
param_names = list(param_grid.keys())

best_score = -float('inf')
best_params = None
best_model = None

for combo in param_combinations:
    params = dict(zip(param_names, combo))
    print(f"\nTesting hyperparams: {params}")

    model = EncoderDecoder(input_channels=CHANNELS_NUM * WAVELET_NUM, output_channels=5)

    trained_model = train(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        num_epochs=params['num_epochs'],
        lr=params['lr'],
        alpha=params['alpha'],
        weight_decay=params['weight_decay'],
        device='cuda'
    )

    # Evaluate final Pearson correlation from the model
    actuals, predictions = test_model(model, val_loader, device=DEVICE)
    final_pearson = pearson_correlation_metric(torch.tensor(predictions), torch.tensor(actuals)).item()
    print(f"Final Pearson score: {final_pearson:.4f}")

    if final_pearson > best_score:
        best_score = final_pearson
        best_params = params
        best_model = trained_model

print(f"\nBest hyperparameters: {best_params}")
print(f"Best Pearson score: {best_score:.4f}")
# Out:
# Testing hyperparams: {'lr': 0.005, 'alpha': 0.3, 'weight_decay': 0.0001, 'num_epochs': 50}
# Epoch 1/50 - Train Loss: 0.0841, Train Corr: 0.8943
# Epoch 1/50 - Val Loss: 0.0256, Val Corr: 0.9361, Pearson Corr: 0.3653
# Epoch 2/50 - Train Loss: 0.0076, Train Corr: 0.9805
# Epoch 2/50 - Val Loss: 0.0229, Val Corr: 0.9427, Pearson Corr: 0.4035
# Epoch 3/50 - Train Loss: 0.0038, Train Corr: 0.9903
# Epoch 3/50 - Val Loss: 0.0216, Val Corr: 0.9468, Pearson Corr: 0.4327
# Epoch 4/50 - Train Loss: 0.0025, Train Corr: 0.9936
# Epoch 4/50 - Val Loss: 0.0208, Val Corr: 0.9488, Pearson Corr: 0.4323
# Epoch 5/50 - Train Loss: 0.0019, Train Corr: 0.9953
# Epoch 5/50 - Val Loss: 0.0201, Val Corr: 0.9507, Pearson Corr: 0.4533
# Epoch 6/50 - Train Loss: 0.0015, Train Corr: 0.9963
# Epoch 6/50 - Val Loss: 0.0198, Val Corr: 0.9517, Pearson Corr: 0.4331
# Epoch 7/50 - Train Loss: 0.0013, Train Corr: 0.9967
# Epoch 7/50 - Val Loss: 0.0209, Val Corr: 0.9496, Pearson Corr: 0.3524
# Epoch 8/50 - Train Loss: 0.0016, Train Corr: 0.9961
# Epoch 8/50 - Val Loss: 0.0211, Val Corr: 0.9486, Pearson Corr: 0.4254
# Epoch 9/50 - Train Loss: 0.0010, Train Corr: 0.9976
# Epoch 9/50 - Val Loss: 0.0206, Val Corr: 0.9498, Pearson Corr: 0.4386
# Epoch 10/50 - Train Loss: 0.0009, Train Corr: 0.9979
# Epoch 10/50 - Val Loss: 0.0204, Val Corr: 0.9504, Pearson Corr: 0.4434
# Epoch 11/50 - Train Loss: 0.0008, Train Corr: 0.9981
# Epoch 11/50 - Val Loss: 0.0204, Val Corr: 0.9503, Pearson Corr: 0.4482
# Epoch 12/50 - Train Loss: 0.0007, Train Corr: 0.9983
# Epoch 12/50 - Val Loss: 0.0207, Val Corr: 0.9495, Pearson Corr: 0.4468
# Epoch 13/50 - Train Loss: 0.0007, Train Corr: 0.9984
# Epoch 13/50 - Val Loss: 0.0215, Val Corr: 0.9473, Pearson Corr: 0.4138
# Epoch 14/50 - Train Loss: 0.0006, Train Corr: 0.9985
# Epoch 14/50 - Val Loss: 0.0213, Val Corr: 0.9478, Pearson Corr: 0.4272
# Epoch 15/50 - Train Loss: 0.0006, Train Corr: 0.9987
# Epoch 15/50 - Val Loss: 0.0214, Val Corr: 0.9474, Pearson Corr: 0.4517
# Epoch 16/50 - Train Loss: 0.0005, Train Corr: 0.9987
# Epoch 16/50 - Val Loss: 0.0205, Val Corr: 0.9499, Pearson Corr: 0.4533
# Epoch 17/50 - Train Loss: 0.0005, Train Corr: 0.9988
# Epoch 17/50 - Val Loss: 0.0209, Val Corr: 0.9486, Pearson Corr: 0.4566
# Epoch 18/50 - Train Loss: 0.0005, Train Corr: 0.9989
# Epoch 18/50 - Val Loss: 0.0214, Val Corr: 0.9472, Pearson Corr: 0.4625
# Epoch 19/50 - Train Loss: 0.0005, Train Corr: 0.9989
# Epoch 19/50 - Val Loss: 0.0213, Val Corr: 0.9478, Pearson Corr: 0.4382
# Epoch 20/50 - Train Loss: 0.0004, Train Corr: 0.9989
# Epoch 20/50 - Val Loss: 0.0197, Val Corr: 0.9508, Pearson Corr: 0.4573
# Epoch 21/50 - Train Loss: 0.0008, Train Corr: 0.9980
# Epoch 21/50 - Val Loss: 0.0209, Val Corr: 0.9487, Pearson Corr: 0.4506
# Epoch 22/50 - Train Loss: 0.0004, Train Corr: 0.9990
# Epoch 22/50 - Val Loss: 0.0213, Val Corr: 0.9477, Pearson Corr: 0.4255
# Epoch 23/50 - Train Loss: 0.0004, Train Corr: 0.9991
# Epoch 23/50 - Val Loss: 0.0210, Val Corr: 0.9486, Pearson Corr: 0.4444
# Epoch 24/50 - Train Loss: 0.0004, Train Corr: 0.9990
# Epoch 24/50 - Val Loss: 0.0207, Val Corr: 0.9489, Pearson Corr: 0.4479
# Epoch 25/50 - Train Loss: 0.0004, Train Corr: 0.9991
# Epoch 25/50 - Val Loss: 0.0206, Val Corr: 0.9490, Pearson Corr: 0.4410
# Epoch 26/50 - Train Loss: 0.0003, Train Corr: 0.9992
# Epoch 26/50 - Val Loss: 0.0209, Val Corr: 0.9492, Pearson Corr: 0.4167
# Epoch 27/50 - Train Loss: 0.0003, Train Corr: 0.9993
# Epoch 27/50 - Val Loss: 0.0214, Val Corr: 0.9477, Pearson Corr: 0.4302
# Epoch 28/50 - Train Loss: 0.0006, Train Corr: 0.9985
# Epoch 28/50 - Val Loss: 0.0212, Val Corr: 0.9478, Pearson Corr: 0.4482
# Epoch 29/50 - Train Loss: 0.0004, Train Corr: 0.9992
# Epoch 29/50 - Val Loss: 0.0206, Val Corr: 0.9496, Pearson Corr: 0.4382
# Epoch 30/50 - Train Loss: 0.0003, Train Corr: 0.9993
# Epoch 30/50 - Val Loss: 0.0212, Val Corr: 0.9482, Pearson Corr: 0.4268
# Epoch 31/50 - Train Loss: 0.0003, Train Corr: 0.9993
# Epoch 31/50 - Val Loss: 0.0214, Val Corr: 0.9472, Pearson Corr: 0.4321
# Epoch 32/50 - Train Loss: 0.0003, Train Corr: 0.9993
# Epoch 32/50 - Val Loss: 0.0211, Val Corr: 0.9488, Pearson Corr: 0.4425
# Epoch 33/50 - Train Loss: 0.0003, Train Corr: 0.9993
# Epoch 33/50 - Val Loss: 0.0209, Val Corr: 0.9489, Pearson Corr: 0.4504
# Epoch 34/50 - Train Loss: 0.0003, Train Corr: 0.9994
# Epoch 34/50 - Val Loss: 0.0209, Val Corr: 0.9487, Pearson Corr: 0.4523
# Epoch 35/50 - Train Loss: 0.0003, Train Corr: 0.9994
# Epoch 35/50 - Val Loss: 0.0210, Val Corr: 0.9483, Pearson Corr: 0.4420
# Epoch 36/50 - Train Loss: 0.0003, Train Corr: 0.9994
# Epoch 36/50 - Val Loss: 0.0212, Val Corr: 0.9480, Pearson Corr: 0.4351
# Epoch 37/50 - Train Loss: 0.0002, Train Corr: 0.9994
# Epoch 37/50 - Val Loss: 0.0214, Val Corr: 0.9472, Pearson Corr: 0.4307
# Epoch 38/50 - Train Loss: 0.0002, Train Corr: 0.9994
# Epoch 38/50 - Val Loss: 0.0215, Val Corr: 0.9474, Pearson Corr: 0.4356
# Epoch 39/50 - Train Loss: 0.0002, Train Corr: 0.9995
# Epoch 39/50 - Val Loss: 0.0213, Val Corr: 0.9477, Pearson Corr: 0.4537
# Epoch 40/50 - Train Loss: 0.0002, Train Corr: 0.9995
# Epoch 40/50 - Val Loss: 0.0214, Val Corr: 0.9475, Pearson Corr: 0.4336
# Epoch 41/50 - Train Loss: 0.0006, Train Corr: 0.9985
# Epoch 41/50 - Val Loss: 0.0217, Val Corr: 0.9469, Pearson Corr: 0.4450
# Epoch 42/50 - Train Loss: 0.0003, Train Corr: 0.9993
# Epoch 42/50 - Val Loss: 0.0208, Val Corr: 0.9491, Pearson Corr: 0.4654
# Epoch 43/50 - Train Loss: 0.0002, Train Corr: 0.9994
# Epoch 43/50 - Val Loss: 0.0211, Val Corr: 0.9484, Pearson Corr: 0.4472
# Epoch 44/50 - Train Loss: 0.0002, Train Corr: 0.9995
# Epoch 44/50 - Val Loss: 0.0202, Val Corr: 0.9501, Pearson Corr: 0.4606
# Epoch 45/50 - Train Loss: 0.0002, Train Corr: 0.9995
# Epoch 45/50 - Val Loss: 0.0208, Val Corr: 0.9490, Pearson Corr: 0.4488
# Epoch 46/50 - Train Loss: 0.0002, Train Corr: 0.9995
# Epoch 46/50 - Val Loss: 0.0207, Val Corr: 0.9492, Pearson Corr: 0.4493
# Epoch 47/50 - Train Loss: 0.0002, Train Corr: 0.9996
# Epoch 47/50 - Val Loss: 0.0206, Val Corr: 0.9493, Pearson Corr: 0.4489
# Epoch 48/50 - Train Loss: 0.0003, Train Corr: 0.9993
# Epoch 48/50 - Val Loss: 0.0214, Val Corr: 0.9473, Pearson Corr: 0.4492
# Epoch 49/50 - Train Loss: 0.0002, Train Corr: 0.9995
# Epoch 49/50 - Val Loss: 0.0187, Val Corr: 0.9536, Pearson Corr: 0.4807
# Epoch 50/50 - Train Loss: 0.0007, Train Corr: 0.9981
# Epoch 50/50 - Val Loss: 0.0219, Val Corr: 0.9460, Pearson Corr: 0.4335
# Final Pearson score: 0.4594
#
# Best hyperparameters: {'lr': 0.005, 'alpha': 0.3, 'weight_decay': 0.0001, 'num_epochs': 50}
# Best Pearson score: 0.4594

# %% [markdown]
# ### 2.2 Best Model

# %%
actuals, predictions = test_model(best_model, val_loader, device=DEVICE)
print(actuals.shape, predictions.shape)
# Out:
# (19724, 5, 256) (19724, 5, 256)

# %%
# Print pearon correlation (SotA model 0.67)
final_pearson = pearson_correlation_metric(torch.tensor(predictions), torch.tensor(actuals)).item()
print("Final Pearson Correlation: ", final_pearson)
torch.save(best_model.state_dict(), f"../{SUBJECT_ID}_{final_pearson}.pth")
# Out:
# Final Pearson Correlation:  0.45936787128448486
