# %%
import numpy as np

import matplotlib.pyplot as plt

import torch
from torch.utils.data import DataLoader, Dataset
import torch.nn as nn
import torch.nn.functional as F
from itertools import product


from scipy.ndimage import gaussian_filter1d

# %%
CHANNELS_NUM = 62        # Number of channels in ECoG data
WAVELET_NUM = 40         # Number of wavelets in the frequency range
SAMPLE_RATE = 100        # Final sampling rate for finger flex and ecog data
time_delay_secs = 0.2    # Time delay hyperparameter

# %%
finger_flex_cropped = np.load('data/finger_flex_cropped.npy')
X_spectrogram_cropped = np.load('data/X_spectrogram_cropped.npy')

finger_flex_cropped_val = np.load('data/finger_flex_cropped_val.npy')
X_spectrogram_cropped_val = np.load('data/X_spectrogram_cropped_val.npy')

# %%
class EcogDataset(Dataset):
    def __init__(self, data, data_length):
        self.spectrogram, self.finger_flex = data
        self.spectrogram = self.spectrogram.astype('float32')
        self.finger_flex = self.finger_flex.astype('float32')
        self.data_length = data_length

    def __len__(self):
        return self.spectrogram.shape[2] - self.data_length

    def __getitem__(self, index):
        spectrogram_crop = self.spectrogram[...,index:index+self.data_length]
        finger_flex_crop = self.finger_flex[...,index:index+self.data_length]
        return spectrogram_crop, finger_flex_crop

# %%
data_length = 256

train_dataset = EcogDataset((X_spectrogram_cropped, finger_flex_cropped), data_length)
print(X_spectrogram_cropped.shape, finger_flex_cropped.shape)  
print(len(train_dataset))

val_dataset = EcogDataset((X_spectrogram_cropped_val, finger_flex_cropped_val), data_length)
print(X_spectrogram_cropped_val.shape, finger_flex_cropped_val.shape)  
print(len(val_dataset))
# Out:
# (62, 40, 39980) (5, 39980)
# 39724
# (62, 40, 19980) (5, 19980)
# 19724

# %%
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=128, shuffle=False)

# %%
def plot_ecog_data(train_dataset):
    fig, axs = plt.subplots(2, 1, figsize=(15, 10))
    
    for i in range(min(3, len(train_dataset))):
        x, y = train_dataset[i]
        
        axs[0].set_title('Input ECoG Data (x) - Shape: ' + str(x.shape))

        im = axs[0].imshow(x[0, :, :], aspect='auto', cmap='viridis')
        
        plt.title('Target Data (5 Fingers) - Time Series')
        plt.plot(y.T)
        plt.xlabel('Time Steps')
        plt.ylabel('Finger Movement/Neural Activity')
        plt.legend([f'Finger {i+1}' for i in range(y.shape[0])])
        plt.grid(True, linestyle='--', alpha=0.7)
    
    plt.tight_layout()
    plt.show()
    
    x, y = train_dataset[0]
    print("Input (x) Data Statistics:")
    print(f"Shape: {x.shape}")
    print(f"Mean: {x.mean()}")
    print(f"Std: {x.std()}")
    print(f"Min: {x.min()}")
    print(f"Max: {x.max()}")
    
    print("\nTarget (y) Data Statistics:")
    print(f"Shape: {y.shape}")
    print(f"Mean: {y.mean()}")
    print(f"Std: {y.std()}")
    print(f"Min: {y.min()}")
    print(f"Max: {y.max()}")

plot_ecog_data(train_dataset)
# Out:
# Input (x) Data Statistics:
# Shape: (62, 40, 256)
# Mean: 36.44956970214844
# Std: 112.34618377685547
# Min: -78.30249786376953
# Max: 2913.20654296875
#
# Target (y) Data Statistics:
# Shape: (5, 256)
# Mean: 0.18342195451259613
# Std: 0.038283176720142365
# Min: 0.12006422877311707
# Max: 0.22728414833545685

# %%
class EncoderDecoder(nn.Module):
    def __init__(self, input_channels, output_channels, dropout_rate=0.4):
        super(EncoderDecoder, self).__init__()
        
        # Encoder
        self.enc_block1 = ResidualBlock(input_channels, 32, kernel_size=3, dropout_rate=dropout_rate)
        self.pool1 = nn.MaxPool1d(kernel_size=2, stride=2)
        
        self.enc_block2 = ResidualBlock(32, 64, kernel_size=3, dropout_rate=dropout_rate)
        self.pool2 = nn.MaxPool1d(kernel_size=2, stride=2)
        
        self.enc_block3 = ResidualBlock(64, 128, kernel_size=3, dropout_rate=dropout_rate)
        self.pool3 = nn.MaxPool1d(kernel_size=2, stride=2)
        
        # LSTM with gradient clipping built in
        self.lstm = LSTM_flatten(input_size=128, hidden_size=128, num_layers=1, 
                                    bidirectional=True, batch_first=True)
        
        # Decoder
        self.up1 = nn.Upsample(scale_factor=2, mode='nearest')
        self.dec_block1 = ResidualBlock(256, 128, kernel_size=3, dropout_rate=dropout_rate)
        
        self.up2 = nn.Upsample(scale_factor=2, mode='nearest')
        self.dec_block2 = ResidualBlock(128 + 64, 64, kernel_size=3, dropout_rate=dropout_rate)
        
        self.up3 = nn.Upsample(scale_factor=2, mode='nearest')
        self.dec_block3 = ResidualBlock(64 + 32, 32, kernel_size=3, dropout_rate=dropout_rate)
        
        self.final_conv = nn.Conv1d(32, output_channels, kernel_size=1)
        
        # Initialize weights
        self._initialize_weights()
        
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv1d) or isinstance(m, nn.ConvTranspose1d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm1d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
    
    def forward(self, x):
        batch, elec, freq, time = x.shape
        x = x.reshape(batch, -1, time)
        
        # Encoder
        e1 = self.enc_block1(x)
        p1 = self.pool1(e1)
        
        e2 = self.enc_block2(p1)
        p2 = self.pool2(e2)
        
        e3 = self.enc_block3(p2)
        p3 = self.pool3(e3)
        
        # LSTM
        p3_permuted = p3.permute(0, 2, 1)
        lstm_out, _ = self.lstm(p3_permuted)
        lstm_out = lstm_out.permute(0, 2, 1)
        
        # Decoder
        d1 = self.up1(lstm_out)
        d1 = self.dec_block1(d1)
        
        d2 = self.up2(d1)
        d2 = torch.cat([d2, e2], dim=1)
        d2 = self.dec_block2(d2)
        
        d3 = self.up3(d2)
        d3 = torch.cat([d3, e1], dim=1)
        d3 = self.dec_block3(d3)
        
        output = self.final_conv(d3)
        
        return output

# Residual Block
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, dropout_rate=0.4):
        super(ResidualBlock, self).__init__()
        
        padding = kernel_size // 2
        
        self.conv_block = nn.Sequential(
            nn.Conv1d(in_channels, out_channels, kernel_size=kernel_size, padding=padding),
            nn.BatchNorm1d(out_channels),
            nn.GELU(),
            nn.Dropout(dropout_rate),
            nn.Conv1d(out_channels, out_channels, kernel_size=kernel_size, padding=padding),
            nn.BatchNorm1d(out_channels)
        )
        
        self.skip = nn.Sequential(
            nn.Conv1d(in_channels, out_channels, kernel_size=1, bias=False),
            nn.BatchNorm1d(out_channels)
        ) if in_channels != out_channels else nn.Identity()
        
        self.activation = nn.GELU()
    
    def forward(self, x):
        identity = self.skip(x)
        out = self.conv_block(x)
        out += identity
        return self.activation(out)

class LSTM_flatten(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, bidirectional, batch_first):
        super(LSTM_flatten, self).__init__()
        self.lstm = nn.LSTM(
            input_size=input_size, 
            hidden_size=hidden_size, 
            num_layers=num_layers, 
            bidirectional=bidirectional, 
            batch_first=batch_first
        )
        
    def forward(self, x):
        self.lstm.flatten_parameters()
        output, hidden = self.lstm(x)
        return output, hidden

# %%
def pearson_loss(y_pred, y_true):
    return 1 - pearson_correlation_metric(y_pred, y_true)
    
def pearson_correlation_metric(y_pred, y_true):
    x = y_pred - torch.mean(y_pred)
    y = y_true - torch.mean(y_true)

    numerator = torch.sum(x * y)
    denominator = torch.sqrt(torch.sum(x ** 2)) * torch.sqrt(torch.sum(y ** 2))

    return numerator / (denominator + 1e-6)

def cosine_correlation_metric(x, y):
    cos_metric = nn.CosineSimilarity(dim=-1, eps=1e-08)

    cos_sim = torch.mean(cos_metric(x, y))
    return cos_sim

# %%
def train(model, train_loader, val_loader, num_epochs=100, lr=5e-3, device='cuda', alpha=0.5, weight_decay=1e-4):
    model.to(device)
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    
    train_losses, val_losses = [], []
    train_corrs, val_corrs = [], []
    pearson_losses = []
    
    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        train_corr = 0.0
        
        for batch in train_loader:
            x, y = batch
            x, y = x.to(device), y.to(device)
            
            optimizer.zero_grad()
            pred = model(x)
            
            mse_loss = F.mse_loss(pred, y)
            corr = cosine_correlation_metric(pred, y)
            final_loss = alpha*mse_loss + alpha*(1. - corr)
            
            final_loss.backward()
            optimizer.step()
            
            train_loss += final_loss.item()
            train_corr += corr.item()
        
        train_loss /= len(train_loader)
        train_corr /= len(train_loader)
        train_losses.append(train_loss)
        train_corrs.append(train_corr)
        
        print(f"Epoch {epoch+1}/{num_epochs} - Train Loss: {train_loss:.4f}, Train Corr: {train_corr:.4f}")
        
        model.eval()
        val_loss = 0.0
        val_corr = 0.0
        pearson_loss_sum = 0.0
        with torch.no_grad():
            for batch in val_loader:
                x, y = batch
                x, y = x.to(device), y.to(device)
                
                pred = model(x)
                
                mse_loss = F.mse_loss(pred, y)
                corr = cosine_correlation_metric(pred, y)
                final_loss = alpha*mse_loss + alpha*(1. - corr)
                
                pearson_loss_metric = pearson_correlation_metric(pred, y)
                
                val_loss += final_loss.item()
                val_corr += corr.item()
                pearson_loss_sum += pearson_loss_metric.item()
                
        val_loss /= len(val_loader)
        val_corr /= len(val_loader)
        pearson_loss_sum /= len(val_loader)
        
        val_losses.append(val_loss)
        val_corrs.append(val_corr)
        pearson_losses.append(pearson_loss_sum)
        
        print(f"Epoch {epoch+1}/{num_epochs} - Val Loss: {val_loss:.4f}, Val Corr: {val_corr:.4f}, Pearson Corr: {pearson_loss_sum:.4f}")
    
    # Plot training and validation loss
    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.plot(range(1, num_epochs + 1), train_losses, label='Train Loss', marker='o')
    plt.plot(range(1, num_epochs + 1), val_losses, label='Val Loss', marker='o')
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.title("Training and Validation Loss")

    # Plot correlation metrics
    plt.subplot(1, 2, 2)
    plt.plot(range(1, num_epochs + 1), train_corrs, label='Train Corr', marker='o')
    plt.plot(range(1, num_epochs + 1), val_corrs, label='Val Corr', marker='o')
    plt.plot(range(1, num_epochs + 1), pearson_losses, label='Pearson Corr', marker='o')
    plt.xlabel("Epoch")
    plt.ylabel("Correlation")
    plt.legend()
    plt.title("Training, Validation, Pearson Correlation")

    plt.tight_layout()
    plt.show()
    
    return model

# %%
def test_model(model, val_loader, device='cuda'):
    model.to(device)
    model.eval()

    all_actuals, all_predictions = [], []

    with torch.no_grad():
        for batch in val_loader:
            x, y = batch
            x, y = x.to(device), y.to(device)

            pred = model(x)

            all_actuals.append(y.cpu().numpy())
            all_predictions.append(pred.cpu().numpy())

    all_actuals = np.concatenate(all_actuals, axis=0)
    all_predictions = np.concatenate(all_predictions, axis=0)
    
    all_predictions = gaussian_filter1d(all_predictions, sigma=6, axis=0)

    # Plot the entire time series
    return all_actuals, all_predictions

# %%
param_grid = {
    'lr': [1e-2, 5e-3, 1e-3],
    'alpha': [0.3, 0.5, 0.7],
    'weight_decay': [1e-4, 1e-3],
    'num_epochs': [50]
}

param_combinations = list(product(*param_grid.values()))
param_names = list(param_grid.keys())

best_score = -float('inf')
best_params = None
best_model = None

for combo in param_combinations:
    params = dict(zip(param_names, combo))
    print(f"\nTesting hyperparams: {params}")
    
    model = EncoderDecoder(input_channels=CHANNELS_NUM * WAVELET_NUM, output_channels=5)
    
    trained_model = train(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        num_epochs=params['num_epochs'],
        lr=params['lr'],
        alpha=params['alpha'],
        weight_decay=params['weight_decay'],
        device='cuda'
    )
    
    # Evaluate final Pearson correlation from the model
    actuals, predictions = test_model(model, val_loader)
    final_pearson = pearson_correlation_metric(torch.tensor(predictions), torch.tensor(actuals)).item()
    print(f"Final Pearson score: {final_pearson:.4f}")
    
    if final_pearson > best_score:
        best_score = final_pearson
        best_params = params
        best_model = trained_model
        
print(f"\nBest hyperparameters: {best_params}")
print(f"Best Pearson score: {best_score:.4f}")
# Out:
# Testing hyperparams: {'lr': 0.01, 'alpha': 0.3, 'weight_decay': 0.0001, 'num_epochs': 50}
# Epoch 1/50 - Train Loss: 0.0785, Train Corr: 0.8986
# Epoch 1/50 - Val Loss: 0.0257, Val Corr: 0.9403, Pearson Corr: 0.2832
# Epoch 2/50 - Train Loss: 0.0122, Train Corr: 0.9679
# Epoch 2/50 - Val Loss: 0.0229, Val Corr: 0.9453, Pearson Corr: 0.4978
# Epoch 3/50 - Train Loss: 0.0062, Train Corr: 0.9833
# Epoch 3/50 - Val Loss: 0.0225, Val Corr: 0.9461, Pearson Corr: 0.5286
# Epoch 4/50 - Train Loss: 0.0039, Train Corr: 0.9895
# Epoch 4/50 - Val Loss: 0.0231, Val Corr: 0.9450, Pearson Corr: 0.4976
# Epoch 5/50 - Train Loss: 0.0030, Train Corr: 0.9920
# Epoch 5/50 - Val Loss: 0.0238, Val Corr: 0.9425, Pearson Corr: 0.4947
# Epoch 6/50 - Train Loss: 0.0026, Train Corr: 0.9933
# Epoch 6/50 - Val Loss: 0.0225, Val Corr: 0.9458, Pearson Corr: 0.5231
# Epoch 7/50 - Train Loss: 0.0021, Train Corr: 0.9946
# Epoch 7/50 - Val Loss: 0.0212, Val Corr: 0.9497, Pearson Corr: 0.5266
# Epoch 8/50 - Train Loss: 0.0017, Train Corr: 0.9955
# Epoch 8/50 - Val Loss: 0.0224, Val Corr: 0.9464, Pearson Corr: 0.5205
# Epoch 9/50 - Train Loss: 0.0015, Train Corr: 0.9961
# Epoch 9/50 - Val Loss: 0.0229, Val Corr: 0.9444, Pearson Corr: 0.5335
# Epoch 10/50 - Train Loss: 0.0013, Train Corr: 0.9967
# Epoch 10/50 - Val Loss: 0.0228, Val Corr: 0.9447, Pearson Corr: 0.5244
# Epoch 11/50 - Train Loss: 0.0013, Train Corr: 0.9968
# Epoch 11/50 - Val Loss: 0.0230, Val Corr: 0.9438, Pearson Corr: 0.5210
# Epoch 12/50 - Train Loss: 0.0012, Train Corr: 0.9970
# Epoch 12/50 - Val Loss: 0.0238, Val Corr: 0.9425, Pearson Corr: 0.5044
# Epoch 13/50 - Train Loss: 0.0011, Train Corr: 0.9972
# Epoch 13/50 - Val Loss: 0.0227, Val Corr: 0.9454, Pearson Corr: 0.5200
# Epoch 14/50 - Train Loss: 0.0017, Train Corr: 0.9956
# Epoch 14/50 - Val Loss: 0.0240, Val Corr: 0.9447, Pearson Corr: 0.3963
# Epoch 15/50 - Train Loss: 0.0013, Train Corr: 0.9965
# Epoch 15/50 - Val Loss: 0.0210, Val Corr: 0.9495, Pearson Corr: 0.5522
# Epoch 16/50 - Train Loss: 0.0013, Train Corr: 0.9967
# Epoch 16/50 - Val Loss: 0.0223, Val Corr: 0.9458, Pearson Corr: 0.5378
# Epoch 17/50 - Train Loss: 0.0009, Train Corr: 0.9978
# Epoch 17/50 - Val Loss: 0.0227, Val Corr: 0.9454, Pearson Corr: 0.5091
# Epoch 18/50 - Train Loss: 0.0008, Train Corr: 0.9979
# Epoch 18/50 - Val Loss: 0.0238, Val Corr: 0.9419, Pearson Corr: 0.5046
# Epoch 19/50 - Train Loss: 0.0008, Train Corr: 0.9980
# Epoch 19/50 - Val Loss: 0.0230, Val Corr: 0.9436, Pearson Corr: 0.5455
# Epoch 20/50 - Train Loss: 0.0007, Train Corr: 0.9982
# Epoch 20/50 - Val Loss: 0.0227, Val Corr: 0.9446, Pearson Corr: 0.5389
# Epoch 21/50 - Train Loss: 0.0008, Train Corr: 0.9980
# Epoch 21/50 - Val Loss: 0.0236, Val Corr: 0.9422, Pearson Corr: 0.5167
# Epoch 22/50 - Train Loss: 0.0007, Train Corr: 0.9983
# Epoch 22/50 - Val Loss: 0.0233, Val Corr: 0.9432, Pearson Corr: 0.5283
# Epoch 23/50 - Train Loss: 0.0006, Train Corr: 0.9984
# Epoch 23/50 - Val Loss: 0.0229, Val Corr: 0.9438, Pearson Corr: 0.5384
# Epoch 24/50 - Train Loss: 0.0006, Train Corr: 0.9985
# Epoch 24/50 - Val Loss: 0.0236, Val Corr: 0.9431, Pearson Corr: 0.4902
# Epoch 25/50 - Train Loss: 0.0022, Train Corr: 0.9942
# Epoch 25/50 - Val Loss: 0.0226, Val Corr: 0.9456, Pearson Corr: 0.5263
# Epoch 26/50 - Train Loss: 0.0008, Train Corr: 0.9980
# Epoch 26/50 - Val Loss: 0.0227, Val Corr: 0.9452, Pearson Corr: 0.5186
# Epoch 27/50 - Train Loss: 0.0006, Train Corr: 0.9984
# Epoch 27/50 - Val Loss: 0.0227, Val Corr: 0.9449, Pearson Corr: 0.5333
# Epoch 28/50 - Train Loss: 0.0006, Train Corr: 0.9986
# Epoch 28/50 - Val Loss: 0.0228, Val Corr: 0.9447, Pearson Corr: 0.5385
# Epoch 29/50 - Train Loss: 0.0006, Train Corr: 0.9986
# Epoch 29/50 - Val Loss: 0.0228, Val Corr: 0.9442, Pearson Corr: 0.5326
# Epoch 30/50 - Train Loss: 0.0005, Train Corr: 0.9988
# Epoch 30/50 - Val Loss: 0.0231, Val Corr: 0.9438, Pearson Corr: 0.5272
# Epoch 31/50 - Train Loss: 0.0005, Train Corr: 0.9988
# Epoch 31/50 - Val Loss: 0.0225, Val Corr: 0.9448, Pearson Corr: 0.5458
# Epoch 32/50 - Train Loss: 0.0006, Train Corr: 0.9985
# Epoch 32/50 - Val Loss: 0.0277, Val Corr: 0.9355, Pearson Corr: 0.2654
# Epoch 33/50 - Train Loss: 0.0009, Train Corr: 0.9976
# Epoch 33/50 - Val Loss: 0.0232, Val Corr: 0.9445, Pearson Corr: 0.5149
# Epoch 34/50 - Train Loss: 0.0005, Train Corr: 0.9988
# Epoch 34/50 - Val Loss: 0.0236, Val Corr: 0.9420, Pearson Corr: 0.5284
# Epoch 35/50 - Train Loss: 0.0004, Train Corr: 0.9989
# Epoch 35/50 - Val Loss: 0.0232, Val Corr: 0.9435, Pearson Corr: 0.5308
# Epoch 36/50 - Train Loss: 0.0004, Train Corr: 0.9990
# Epoch 36/50 - Val Loss: 0.0232, Val Corr: 0.9434, Pearson Corr: 0.5298
# Epoch 37/50 - Train Loss: 0.0004, Train Corr: 0.9991
# Epoch 37/50 - Val Loss: 0.0233, Val Corr: 0.9432, Pearson Corr: 0.5347
# Epoch 38/50 - Train Loss: 0.0004, Train Corr: 0.9991
# Epoch 38/50 - Val Loss: 0.0233, Val Corr: 0.9433, Pearson Corr: 0.5291
# Epoch 39/50 - Train Loss: 0.0003, Train Corr: 0.9991
# Epoch 39/50 - Val Loss: 0.0232, Val Corr: 0.9434, Pearson Corr: 0.5344
# Epoch 40/50 - Train Loss: 0.0003, Train Corr: 0.9991
# Epoch 40/50 - Val Loss: 0.0238, Val Corr: 0.9438, Pearson Corr: 0.4546
# Epoch 41/50 - Train Loss: 0.0003, Train Corr: 0.9992
# Epoch 41/50 - Val Loss: 0.0228, Val Corr: 0.9444, Pearson Corr: 0.5418
# Epoch 42/50 - Train Loss: 0.0003, Train Corr: 0.9992
# Epoch 42/50 - Val Loss: 0.0230, Val Corr: 0.9442, Pearson Corr: 0.5326
# Epoch 43/50 - Train Loss: 0.0003, Train Corr: 0.9992
# Epoch 43/50 - Val Loss: 0.0270, Val Corr: 0.9354, Pearson Corr: 0.3461
# Epoch 44/50 - Train Loss: 0.0003, Train Corr: 0.9993
# Epoch 44/50 - Val Loss: 0.0264, Val Corr: 0.9380, Pearson Corr: 0.3737
# Epoch 45/50 - Train Loss: 0.0003, Train Corr: 0.9993
# Epoch 45/50 - Val Loss: 0.0231, Val Corr: 0.9443, Pearson Corr: 0.5208
# Epoch 46/50 - Train Loss: 0.0003, Train Corr: 0.9993
# Epoch 46/50 - Val Loss: 0.0229, Val Corr: 0.9449, Pearson Corr: 0.5293
# Epoch 47/50 - Train Loss: 0.0003, Train Corr: 0.9992
# Epoch 47/50 - Val Loss: 0.0279, Val Corr: 0.9347, Pearson Corr: 0.2660
# Epoch 48/50 - Train Loss: 0.0017, Train Corr: 0.9955
# Epoch 48/50 - Val Loss: 0.0276, Val Corr: 0.9376, Pearson Corr: 0.0990
# Epoch 49/50 - Train Loss: 0.0005, Train Corr: 0.9987
# Epoch 49/50 - Val Loss: 0.0275, Val Corr: 0.9374, Pearson Corr: 0.1359
# Epoch 50/50 - Train Loss: 0.0004, Train Corr: 0.9990
# Epoch 50/50 - Val Loss: 0.0286, Val Corr: 0.9343, Pearson Corr: 0.1197
# Final Pearson score: 0.1677
#
# Testing hyperparams: {'lr': 0.01, 'alpha': 0.3, 'weight_decay': 0.001, 'num_epochs': 50}
# Epoch 1/50 - Train Loss: 0.0558, Train Corr: 0.9114
# Epoch 1/50 - Val Loss: 0.0235, Val Corr: 0.9463, Pearson Corr: 0.3477
# Epoch 2/50 - Train Loss: 0.0098, Train Corr: 0.9738
# Epoch 2/50 - Val Loss: 0.0226, Val Corr: 0.9465, Pearson Corr: 0.4883
# Epoch 3/50 - Train Loss: 0.0052, Train Corr: 0.9858
# Epoch 3/50 - Val Loss: 0.0222, Val Corr: 0.9484, Pearson Corr: 0.4667
# Epoch 4/50 - Train Loss: 0.0035, Train Corr: 0.9905
# Epoch 4/50 - Val Loss: 0.0226, Val Corr: 0.9473, Pearson Corr: 0.5042
# Epoch 5/50 - Train Loss: 0.0027, Train Corr: 0.9926
# Epoch 5/50 - Val Loss: 0.0247, Val Corr: 0.9429, Pearson Corr: 0.3893
# Epoch 6/50 - Train Loss: 0.0022, Train Corr: 0.9943
# Epoch 6/50 - Val Loss: 0.0222, Val Corr: 0.9466, Pearson Corr: 0.5262
# Epoch 7/50 - Train Loss: 0.0017, Train Corr: 0.9955
# Epoch 7/50 - Val Loss: 0.0223, Val Corr: 0.9475, Pearson Corr: 0.4773
# Epoch 8/50 - Train Loss: 0.0015, Train Corr: 0.9960
# Epoch 8/50 - Val Loss: 0.0222, Val Corr: 0.9463, Pearson Corr: 0.5379
# Epoch 9/50 - Train Loss: 0.0014, Train Corr: 0.9965
# Epoch 9/50 - Val Loss: 0.0218, Val Corr: 0.9475, Pearson Corr: 0.5368
# Epoch 10/50 - Train Loss: 0.0012, Train Corr: 0.9968
# Epoch 10/50 - Val Loss: 0.0220, Val Corr: 0.9470, Pearson Corr: 0.5361
# Epoch 11/50 - Train Loss: 0.0011, Train Corr: 0.9971
# Epoch 11/50 - Val Loss: 0.0232, Val Corr: 0.9436, Pearson Corr: 0.5341
# Epoch 12/50 - Train Loss: 0.0011, Train Corr: 0.9971
# Epoch 12/50 - Val Loss: 0.0223, Val Corr: 0.9453, Pearson Corr: 0.5468
# Epoch 13/50 - Train Loss: 0.0009, Train Corr: 0.9976
# Epoch 13/50 - Val Loss: 0.0233, Val Corr: 0.9427, Pearson Corr: 0.5387
# Epoch 14/50 - Train Loss: 0.0012, Train Corr: 0.9969
# Epoch 14/50 - Val Loss: 0.0220, Val Corr: 0.9479, Pearson Corr: 0.5010
# Epoch 15/50 - Train Loss: 0.0011, Train Corr: 0.9972
# Epoch 15/50 - Val Loss: 0.0222, Val Corr: 0.9459, Pearson Corr: 0.5299
# Epoch 16/50 - Train Loss: 0.0008, Train Corr: 0.9981
# Epoch 16/50 - Val Loss: 0.0230, Val Corr: 0.9438, Pearson Corr: 0.5309
# Epoch 17/50 - Train Loss: 0.0007, Train Corr: 0.9983
# Epoch 17/50 - Val Loss: 0.0235, Val Corr: 0.9421, Pearson Corr: 0.5339
# Epoch 18/50 - Train Loss: 0.0007, Train Corr: 0.9983
# Epoch 18/50 - Val Loss: 0.0235, Val Corr: 0.9431, Pearson Corr: 0.5067
# Epoch 19/50 - Train Loss: 0.0007, Train Corr: 0.9983
# Epoch 19/50 - Val Loss: 0.0232, Val Corr: 0.9433, Pearson Corr: 0.5212
# Epoch 20/50 - Train Loss: 0.0006, Train Corr: 0.9985
# Epoch 20/50 - Val Loss: 0.0222, Val Corr: 0.9456, Pearson Corr: 0.5483
# Epoch 21/50 - Train Loss: 0.0006, Train Corr: 0.9985
# Epoch 21/50 - Val Loss: 0.0225, Val Corr: 0.9447, Pearson Corr: 0.5518
# Epoch 22/50 - Train Loss: 0.0009, Train Corr: 0.9977
# Epoch 22/50 - Val Loss: 0.0227, Val Corr: 0.9447, Pearson Corr: 0.5446
# Epoch 23/50 - Train Loss: 0.0006, Train Corr: 0.9986
# Epoch 23/50 - Val Loss: 0.0227, Val Corr: 0.9450, Pearson Corr: 0.5337
# Epoch 24/50 - Train Loss: 0.0005, Train Corr: 0.9988
# Epoch 24/50 - Val Loss: 0.0244, Val Corr: 0.9402, Pearson Corr: 0.5104
# Epoch 25/50 - Train Loss: 0.0005, Train Corr: 0.9988
# Epoch 25/50 - Val Loss: 0.0243, Val Corr: 0.9404, Pearson Corr: 0.5030
# Epoch 26/50 - Train Loss: 0.0005, Train Corr: 0.9988
# Epoch 26/50 - Val Loss: 0.0230, Val Corr: 0.9441, Pearson Corr: 0.5453
# Epoch 27/50 - Train Loss: 0.0004, Train Corr: 0.9990
# Epoch 27/50 - Val Loss: 0.0234, Val Corr: 0.9422, Pearson Corr: 0.5445
# Epoch 28/50 - Train Loss: 0.0004, Train Corr: 0.9990
# Epoch 28/50 - Val Loss: 0.0244, Val Corr: 0.9400, Pearson Corr: 0.5232
# Epoch 29/50 - Train Loss: 0.0020, Train Corr: 0.9947
# Epoch 29/50 - Val Loss: 0.0236, Val Corr: 0.9422, Pearson Corr: 0.5219
# Epoch 30/50 - Train Loss: 0.0006, Train Corr: 0.9983
# Epoch 30/50 - Val Loss: 0.0239, Val Corr: 0.9409, Pearson Corr: 0.5284
# Epoch 31/50 - Train Loss: 0.0006, Train Corr: 0.9983
# Epoch 31/50 - Val Loss: 0.0238, Val Corr: 0.9414, Pearson Corr: 0.5238
# Epoch 32/50 - Train Loss: 0.0005, Train Corr: 0.9989
# Epoch 32/50 - Val Loss: 0.0244, Val Corr: 0.9392, Pearson Corr: 0.5385
# Epoch 33/50 - Train Loss: 0.0004, Train Corr: 0.9989
# Epoch 33/50 - Val Loss: 0.0238, Val Corr: 0.9411, Pearson Corr: 0.5429
# Epoch 34/50 - Train Loss: 0.0004, Train Corr: 0.9990
# Epoch 34/50 - Val Loss: 0.0239, Val Corr: 0.9405, Pearson Corr: 0.5502
# Epoch 35/50 - Train Loss: 0.0004, Train Corr: 0.9991
# Epoch 35/50 - Val Loss: 0.0234, Val Corr: 0.9419, Pearson Corr: 0.5527
# Epoch 36/50 - Train Loss: 0.0003, Train Corr: 0.9991
# Epoch 36/50 - Val Loss: 0.0243, Val Corr: 0.9399, Pearson Corr: 0.5238
# Epoch 37/50 - Train Loss: 0.0003, Train Corr: 0.9992
# Epoch 37/50 - Val Loss: 0.0258, Val Corr: 0.9353, Pearson Corr: 0.5222
# Epoch 38/50 - Train Loss: 0.0003, Train Corr: 0.9992
# Epoch 38/50 - Val Loss: 0.0242, Val Corr: 0.9401, Pearson Corr: 0.5349
# Epoch 39/50 - Train Loss: 0.0003, Train Corr: 0.9993
# Epoch 39/50 - Val Loss: 0.0234, Val Corr: 0.9421, Pearson Corr: 0.5533
# Epoch 40/50 - Train Loss: 0.0003, Train Corr: 0.9993
# Epoch 40/50 - Val Loss: 0.0239, Val Corr: 0.9410, Pearson Corr: 0.5279
# Epoch 41/50 - Train Loss: 0.0003, Train Corr: 0.9993
# Epoch 41/50 - Val Loss: 0.0239, Val Corr: 0.9413, Pearson Corr: 0.5143
# Epoch 42/50 - Train Loss: 0.0003, Train Corr: 0.9993
# Epoch 42/50 - Val Loss: 0.0235, Val Corr: 0.9422, Pearson Corr: 0.5326
# Epoch 43/50 - Train Loss: 0.0016, Train Corr: 0.9957
# Epoch 43/50 - Val Loss: 0.0289, Val Corr: 0.9420, Pearson Corr: 0.0561
# Epoch 44/50 - Train Loss: 0.0005, Train Corr: 0.9986
# Epoch 44/50 - Val Loss: 0.0302, Val Corr: 0.9409, Pearson Corr: 0.0558
# Epoch 45/50 - Train Loss: 0.0004, Train Corr: 0.9990
# Epoch 45/50 - Val Loss: 0.0280, Val Corr: 0.9436, Pearson Corr: 0.0995
# Epoch 46/50 - Train Loss: 0.0003, Train Corr: 0.9992
# Epoch 46/50 - Val Loss: 0.0252, Val Corr: 0.9452, Pearson Corr: 0.2802
# Epoch 47/50 - Train Loss: 0.0003, Train Corr: 0.9993
# Epoch 47/50 - Val Loss: 0.0239, Val Corr: 0.9456, Pearson Corr: 0.3771
# Epoch 48/50 - Train Loss: 0.0003, Train Corr: 0.9993
# Epoch 48/50 - Val Loss: 0.0228, Val Corr: 0.9475, Pearson Corr: 0.4414
# Epoch 49/50 - Train Loss: 0.0003, Train Corr: 0.9994
# Epoch 49/50 - Val Loss: 0.0220, Val Corr: 0.9474, Pearson Corr: 0.5169
# Epoch 50/50 - Train Loss: 0.0002, Train Corr: 0.9994
# Epoch 50/50 - Val Loss: 0.0221, Val Corr: 0.9460, Pearson Corr: 0.5410
# Final Pearson score: 0.5776
#
# Testing hyperparams: {'lr': 0.01, 'alpha': 0.5, 'weight_decay': 0.0001, 'num_epochs': 50}
# Epoch 1/50 - Train Loss: 0.0932, Train Corr: 0.9106
# Epoch 1/50 - Val Loss: 0.0377, Val Corr: 0.9452, Pearson Corr: 0.5158
# Epoch 2/50 - Train Loss: 0.0149, Train Corr: 0.9761
# Epoch 2/50 - Val Loss: 0.0404, Val Corr: 0.9419, Pearson Corr: 0.4616
# Epoch 3/50 - Train Loss: 0.0072, Train Corr: 0.9882
# Epoch 3/50 - Val Loss: 0.0376, Val Corr: 0.9448, Pearson Corr: 0.5546
# Epoch 4/50 - Train Loss: 0.0047, Train Corr: 0.9924
# Epoch 4/50 - Val Loss: 0.0385, Val Corr: 0.9436, Pearson Corr: 0.5302
# Epoch 5/50 - Train Loss: 0.0035, Train Corr: 0.9945
# Epoch 5/50 - Val Loss: 0.0375, Val Corr: 0.9450, Pearson Corr: 0.5507
# Epoch 6/50 - Train Loss: 0.0029, Train Corr: 0.9954
# Epoch 6/50 - Val Loss: 0.0366, Val Corr: 0.9470, Pearson Corr: 0.5394
# Epoch 7/50 - Train Loss: 0.0023, Train Corr: 0.9965
# Epoch 7/50 - Val Loss: 0.0381, Val Corr: 0.9441, Pearson Corr: 0.5394
# Epoch 8/50 - Train Loss: 0.0036, Train Corr: 0.9943
# Epoch 8/50 - Val Loss: 0.0441, Val Corr: 0.9394, Pearson Corr: 0.2119
# Epoch 9/50 - Train Loss: 0.0033, Train Corr: 0.9949
# Epoch 9/50 - Val Loss: 0.0366, Val Corr: 0.9470, Pearson Corr: 0.5416
# Epoch 10/50 - Train Loss: 0.0019, Train Corr: 0.9971
# Epoch 10/50 - Val Loss: 0.0372, Val Corr: 0.9457, Pearson Corr: 0.5509
# Epoch 11/50 - Train Loss: 0.0017, Train Corr: 0.9975
# Epoch 11/50 - Val Loss: 0.0374, Val Corr: 0.9450, Pearson Corr: 0.5614
# Epoch 12/50 - Train Loss: 0.0015, Train Corr: 0.9977
# Epoch 12/50 - Val Loss: 0.0362, Val Corr: 0.9478, Pearson Corr: 0.5040
# Epoch 13/50 - Train Loss: 0.0026, Train Corr: 0.9961
# Epoch 13/50 - Val Loss: 0.0352, Val Corr: 0.9486, Pearson Corr: 0.5755
# Epoch 14/50 - Train Loss: 0.0014, Train Corr: 0.9979
# Epoch 14/50 - Val Loss: 0.0363, Val Corr: 0.9469, Pearson Corr: 0.5637
# Epoch 15/50 - Train Loss: 0.0012, Train Corr: 0.9983
# Epoch 15/50 - Val Loss: 0.0362, Val Corr: 0.9468, Pearson Corr: 0.5733
# Epoch 16/50 - Train Loss: 0.0012, Train Corr: 0.9982
# Epoch 16/50 - Val Loss: 0.0364, Val Corr: 0.9467, Pearson Corr: 0.5719
# Epoch 17/50 - Train Loss: 0.0011, Train Corr: 0.9984
# Epoch 17/50 - Val Loss: 0.0374, Val Corr: 0.9450, Pearson Corr: 0.5689
# Epoch 18/50 - Train Loss: 0.0011, Train Corr: 0.9984
# Epoch 18/50 - Val Loss: 0.0402, Val Corr: 0.9410, Pearson Corr: 0.4898
# Epoch 19/50 - Train Loss: 0.0010, Train Corr: 0.9985
# Epoch 19/50 - Val Loss: 0.0386, Val Corr: 0.9431, Pearson Corr: 0.5452
# Epoch 20/50 - Train Loss: 0.0036, Train Corr: 0.9943
# Epoch 20/50 - Val Loss: 0.0361, Val Corr: 0.9474, Pearson Corr: 0.5634
# Epoch 21/50 - Train Loss: 0.0014, Train Corr: 0.9979
# Epoch 21/50 - Val Loss: 0.0367, Val Corr: 0.9465, Pearson Corr: 0.5541
# Epoch 22/50 - Train Loss: 0.0010, Train Corr: 0.9984
# Epoch 22/50 - Val Loss: 0.0382, Val Corr: 0.9439, Pearson Corr: 0.5558
# Epoch 23/50 - Train Loss: 0.0011, Train Corr: 0.9982
# Epoch 23/50 - Val Loss: 0.0382, Val Corr: 0.9524, Pearson Corr: 0.4125
# Epoch 24/50 - Train Loss: 0.0046, Train Corr: 0.9934
# Epoch 24/50 - Val Loss: 0.0412, Val Corr: 0.9408, Pearson Corr: 0.4418
# Epoch 25/50 - Train Loss: 0.0014, Train Corr: 0.9979
# Epoch 25/50 - Val Loss: 0.0370, Val Corr: 0.9459, Pearson Corr: 0.5625
# Epoch 26/50 - Train Loss: 0.0011, Train Corr: 0.9984
# Epoch 26/50 - Val Loss: 0.0378, Val Corr: 0.9442, Pearson Corr: 0.5664
# Epoch 27/50 - Train Loss: 0.0010, Train Corr: 0.9985
# Epoch 27/50 - Val Loss: 0.0372, Val Corr: 0.9449, Pearson Corr: 0.5659
# Epoch 28/50 - Train Loss: 0.0009, Train Corr: 0.9987
# Epoch 28/50 - Val Loss: 0.0377, Val Corr: 0.9440, Pearson Corr: 0.5747
# Epoch 29/50 - Train Loss: 0.0009, Train Corr: 0.9986
# Epoch 29/50 - Val Loss: 0.0379, Val Corr: 0.9436, Pearson Corr: 0.5697
# Epoch 30/50 - Train Loss: 0.0008, Train Corr: 0.9988
# Epoch 30/50 - Val Loss: 0.0378, Val Corr: 0.9443, Pearson Corr: 0.5647
# Epoch 31/50 - Train Loss: 0.0008, Train Corr: 0.9988
# Epoch 31/50 - Val Loss: 0.0391, Val Corr: 0.9420, Pearson Corr: 0.5555
# Epoch 32/50 - Train Loss: 0.0007, Train Corr: 0.9989
# Epoch 32/50 - Val Loss: 0.0394, Val Corr: 0.9414, Pearson Corr: 0.5556
# Epoch 33/50 - Train Loss: 0.0007, Train Corr: 0.9989
# Epoch 33/50 - Val Loss: 0.0427, Val Corr: 0.9380, Pearson Corr: 0.4626
# Epoch 34/50 - Train Loss: 0.0007, Train Corr: 0.9990
# Epoch 34/50 - Val Loss: 0.0418, Val Corr: 0.9388, Pearson Corr: 0.4674
# Epoch 35/50 - Train Loss: 0.0006, Train Corr: 0.9990
# Epoch 35/50 - Val Loss: 0.0397, Val Corr: 0.9409, Pearson Corr: 0.5498
# Epoch 36/50 - Train Loss: 0.0019, Train Corr: 0.9969
# Epoch 36/50 - Val Loss: 0.0453, Val Corr: 0.9343, Pearson Corr: 0.3572
# Epoch 37/50 - Train Loss: 0.0015, Train Corr: 0.9976
# Epoch 37/50 - Val Loss: 0.0457, Val Corr: 0.9347, Pearson Corr: 0.2897
# Epoch 38/50 - Train Loss: 0.0009, Train Corr: 0.9986
# Epoch 38/50 - Val Loss: 0.0439, Val Corr: 0.9376, Pearson Corr: 0.3137
# Epoch 39/50 - Train Loss: 0.0007, Train Corr: 0.9989
# Epoch 39/50 - Val Loss: 0.0426, Val Corr: 0.9394, Pearson Corr: 0.3289
# Epoch 40/50 - Train Loss: 0.0007, Train Corr: 0.9990
# Epoch 40/50 - Val Loss: 0.0434, Val Corr: 0.9379, Pearson Corr: 0.3310
# Epoch 41/50 - Train Loss: 0.0006, Train Corr: 0.9991
# Epoch 41/50 - Val Loss: 0.0442, Val Corr: 0.9357, Pearson Corr: 0.3686
# Epoch 42/50 - Train Loss: 0.0006, Train Corr: 0.9992
# Epoch 42/50 - Val Loss: 0.0433, Val Corr: 0.9380, Pearson Corr: 0.3208
# Epoch 43/50 - Train Loss: 0.0006, Train Corr: 0.9991
# Epoch 43/50 - Val Loss: 0.0399, Val Corr: 0.9419, Pearson Corr: 0.4411
# Epoch 44/50 - Train Loss: 0.0005, Train Corr: 0.9992
# Epoch 44/50 - Val Loss: 0.0393, Val Corr: 0.9427, Pearson Corr: 0.4400
# Epoch 45/50 - Train Loss: 0.0005, Train Corr: 0.9992
# Epoch 45/50 - Val Loss: 0.0402, Val Corr: 0.9412, Pearson Corr: 0.4655
# Epoch 46/50 - Train Loss: 0.0005, Train Corr: 0.9993
# Epoch 46/50 - Val Loss: 0.0372, Val Corr: 0.9450, Pearson Corr: 0.5585
# Epoch 47/50 - Train Loss: 0.0005, Train Corr: 0.9993
# Epoch 47/50 - Val Loss: 0.0389, Val Corr: 0.9432, Pearson Corr: 0.4892
# Epoch 48/50 - Train Loss: 0.0005, Train Corr: 0.9993
# Epoch 48/50 - Val Loss: 0.0390, Val Corr: 0.9426, Pearson Corr: 0.5285
# Epoch 49/50 - Train Loss: 0.0004, Train Corr: 0.9993
# Epoch 49/50 - Val Loss: 0.0385, Val Corr: 0.9432, Pearson Corr: 0.5647
# Epoch 50/50 - Train Loss: 0.0010, Train Corr: 0.9983
# Epoch 50/50 - Val Loss: 0.0448, Val Corr: 0.9393, Pearson Corr: 0.0515
# Final Pearson score: 0.0736
#
# Testing hyperparams: {'lr': 0.01, 'alpha': 0.5, 'weight_decay': 0.001, 'num_epochs': 50}
# Epoch 1/50 - Train Loss: 0.1340, Train Corr: 0.9025
# Epoch 1/50 - Val Loss: 0.0405, Val Corr: 0.9440, Pearson Corr: 0.3054
# Epoch 2/50 - Train Loss: 0.0220, Train Corr: 0.9667
# Epoch 2/50 - Val Loss: 0.0365, Val Corr: 0.9488, Pearson Corr: 0.4874
# Epoch 3/50 - Train Loss: 0.0103, Train Corr: 0.9836
# Epoch 3/50 - Val Loss: 0.0385, Val Corr: 0.9437, Pearson Corr: 0.5211
# Epoch 4/50 - Train Loss: 0.0072, Train Corr: 0.9884
# Epoch 4/50 - Val Loss: 0.0352, Val Corr: 0.9487, Pearson Corr: 0.5443
# Epoch 5/50 - Train Loss: 0.0058, Train Corr: 0.9908
# Epoch 5/50 - Val Loss: 0.0399, Val Corr: 0.9415, Pearson Corr: 0.4934
# Epoch 6/50 - Train Loss: 0.0045, Train Corr: 0.9929
# Epoch 6/50 - Val Loss: 0.0410, Val Corr: 0.9392, Pearson Corr: 0.5023
# Epoch 7/50 - Train Loss: 0.0038, Train Corr: 0.9941
# Epoch 7/50 - Val Loss: 0.0380, Val Corr: 0.9450, Pearson Corr: 0.5117
# Epoch 8/50 - Train Loss: 0.0032, Train Corr: 0.9951
# Epoch 8/50 - Val Loss: 0.0410, Val Corr: 0.9394, Pearson Corr: 0.5019
# Epoch 9/50 - Train Loss: 0.0036, Train Corr: 0.9944
# Epoch 9/50 - Val Loss: 0.0397, Val Corr: 0.9420, Pearson Corr: 0.5098
# Epoch 10/50 - Train Loss: 0.0026, Train Corr: 0.9960
# Epoch 10/50 - Val Loss: 0.0385, Val Corr: 0.9438, Pearson Corr: 0.5219
# Epoch 11/50 - Train Loss: 0.0027, Train Corr: 0.9959
# Epoch 11/50 - Val Loss: 0.0380, Val Corr: 0.9456, Pearson Corr: 0.4500
# Epoch 12/50 - Train Loss: 0.0028, Train Corr: 0.9958
# Epoch 12/50 - Val Loss: 0.0414, Val Corr: 0.9391, Pearson Corr: 0.4994
# Epoch 13/50 - Train Loss: 0.0021, Train Corr: 0.9969
# Epoch 13/50 - Val Loss: 0.0379, Val Corr: 0.9443, Pearson Corr: 0.5282
# Epoch 14/50 - Train Loss: 0.0020, Train Corr: 0.9969
# Epoch 14/50 - Val Loss: 0.0400, Val Corr: 0.9413, Pearson Corr: 0.5042
# Epoch 15/50 - Train Loss: 0.0018, Train Corr: 0.9973
# Epoch 15/50 - Val Loss: 0.0401, Val Corr: 0.9411, Pearson Corr: 0.5033
# Epoch 16/50 - Train Loss: 0.0017, Train Corr: 0.9974
# Epoch 16/50 - Val Loss: 0.0421, Val Corr: 0.9371, Pearson Corr: 0.5206
# Epoch 17/50 - Train Loss: 0.0042, Train Corr: 0.9933
# Epoch 17/50 - Val Loss: 0.0486, Val Corr: 0.9323, Pearson Corr: 0.2258
# Epoch 18/50 - Train Loss: 0.0018, Train Corr: 0.9974
# Epoch 18/50 - Val Loss: 0.0496, Val Corr: 0.9308, Pearson Corr: 0.1809
# Epoch 19/50 - Train Loss: 0.0015, Train Corr: 0.9977
# Epoch 19/50 - Val Loss: 0.0462, Val Corr: 0.9355, Pearson Corr: 0.2637
# Epoch 20/50 - Train Loss: 0.0015, Train Corr: 0.9978
# Epoch 20/50 - Val Loss: 0.0433, Val Corr: 0.9372, Pearson Corr: 0.4310
# Epoch 21/50 - Train Loss: 0.0014, Train Corr: 0.9980
# Epoch 21/50 - Val Loss: 0.0420, Val Corr: 0.9393, Pearson Corr: 0.4375
# Epoch 22/50 - Train Loss: 0.0012, Train Corr: 0.9982
# Epoch 22/50 - Val Loss: 0.0409, Val Corr: 0.9407, Pearson Corr: 0.4744
# Epoch 23/50 - Train Loss: 0.0013, Train Corr: 0.9981
# Epoch 23/50 - Val Loss: 0.0409, Val Corr: 0.9405, Pearson Corr: 0.4691
# Epoch 24/50 - Train Loss: 0.0015, Train Corr: 0.9977
# Epoch 24/50 - Val Loss: 0.0404, Val Corr: 0.9404, Pearson Corr: 0.5064
# Epoch 25/50 - Train Loss: 0.0011, Train Corr: 0.9983
# Epoch 25/50 - Val Loss: 0.0412, Val Corr: 0.9397, Pearson Corr: 0.4762
# Epoch 26/50 - Train Loss: 0.0010, Train Corr: 0.9985
# Epoch 26/50 - Val Loss: 0.0400, Val Corr: 0.9414, Pearson Corr: 0.5169
# Epoch 27/50 - Train Loss: 0.0010, Train Corr: 0.9985
# Epoch 27/50 - Val Loss: 0.0419, Val Corr: 0.9383, Pearson Corr: 0.5019
# Epoch 28/50 - Train Loss: 0.0009, Train Corr: 0.9986
# Epoch 28/50 - Val Loss: 0.0390, Val Corr: 0.9426, Pearson Corr: 0.5261
# Epoch 29/50 - Train Loss: 0.0009, Train Corr: 0.9986
# Epoch 29/50 - Val Loss: 0.0381, Val Corr: 0.9435, Pearson Corr: 0.5425
# Epoch 30/50 - Train Loss: 0.0031, Train Corr: 0.9950
# Epoch 30/50 - Val Loss: 0.0385, Val Corr: 0.9434, Pearson Corr: 0.5448
# Epoch 31/50 - Train Loss: 0.0011, Train Corr: 0.9984
# Epoch 31/50 - Val Loss: 0.0405, Val Corr: 0.9405, Pearson Corr: 0.5173
# Epoch 32/50 - Train Loss: 0.0009, Train Corr: 0.9986
# Epoch 32/50 - Val Loss: 0.0399, Val Corr: 0.9411, Pearson Corr: 0.5281
# Epoch 33/50 - Train Loss: 0.0009, Train Corr: 0.9986
# Epoch 33/50 - Val Loss: 0.0393, Val Corr: 0.9423, Pearson Corr: 0.5361
# Epoch 34/50 - Train Loss: 0.0008, Train Corr: 0.9989
# Epoch 34/50 - Val Loss: 0.0406, Val Corr: 0.9401, Pearson Corr: 0.5156
# Epoch 35/50 - Train Loss: 0.0007, Train Corr: 0.9989
# Epoch 35/50 - Val Loss: 0.0400, Val Corr: 0.9409, Pearson Corr: 0.5284
# Epoch 36/50 - Train Loss: 0.0007, Train Corr: 0.9990
# Epoch 36/50 - Val Loss: 0.0398, Val Corr: 0.9414, Pearson Corr: 0.5296
# Epoch 37/50 - Train Loss: 0.0030, Train Corr: 0.9952
# Epoch 37/50 - Val Loss: 0.0468, Val Corr: 0.9329, Pearson Corr: 0.3235
# Epoch 38/50 - Train Loss: 0.0010, Train Corr: 0.9984
# Epoch 38/50 - Val Loss: 0.0419, Val Corr: 0.9384, Pearson Corr: 0.4846
# Epoch 39/50 - Train Loss: 0.0008, Train Corr: 0.9988
# Epoch 39/50 - Val Loss: 0.0396, Val Corr: 0.9415, Pearson Corr: 0.5343
# Epoch 40/50 - Train Loss: 0.0007, Train Corr: 0.9989
# Epoch 40/50 - Val Loss: 0.0393, Val Corr: 0.9420, Pearson Corr: 0.5359
# Epoch 41/50 - Train Loss: 0.0008, Train Corr: 0.9988
# Epoch 41/50 - Val Loss: 0.0420, Val Corr: 0.9377, Pearson Corr: 0.5045
# Epoch 42/50 - Train Loss: 0.0006, Train Corr: 0.9990
# Epoch 42/50 - Val Loss: 0.0404, Val Corr: 0.9405, Pearson Corr: 0.5146
# Epoch 43/50 - Train Loss: 0.0006, Train Corr: 0.9991
# Epoch 43/50 - Val Loss: 0.0394, Val Corr: 0.9417, Pearson Corr: 0.5283
# Epoch 44/50 - Train Loss: 0.0006, Train Corr: 0.9991
# Epoch 44/50 - Val Loss: 0.0391, Val Corr: 0.9423, Pearson Corr: 0.5420
# Epoch 45/50 - Train Loss: 0.0005, Train Corr: 0.9992
# Epoch 45/50 - Val Loss: 0.0400, Val Corr: 0.9412, Pearson Corr: 0.5239
# Epoch 46/50 - Train Loss: 0.0005, Train Corr: 0.9992
# Epoch 46/50 - Val Loss: 0.0392, Val Corr: 0.9421, Pearson Corr: 0.5386
# Epoch 47/50 - Train Loss: 0.0005, Train Corr: 0.9993
# Epoch 47/50 - Val Loss: 0.0402, Val Corr: 0.9406, Pearson Corr: 0.5193
# Epoch 48/50 - Train Loss: 0.0005, Train Corr: 0.9992
# Epoch 48/50 - Val Loss: 0.0386, Val Corr: 0.9431, Pearson Corr: 0.5362
# Epoch 49/50 - Train Loss: 0.0031, Train Corr: 0.9949
# Epoch 49/50 - Val Loss: 0.0467, Val Corr: 0.9367, Pearson Corr: 0.2195
# Epoch 50/50 - Train Loss: 0.0010, Train Corr: 0.9985
# Epoch 50/50 - Val Loss: 0.0452, Val Corr: 0.9364, Pearson Corr: 0.3101
# Final Pearson score: 0.3193
#
# Testing hyperparams: {'lr': 0.01, 'alpha': 0.7, 'weight_decay': 0.0001, 'num_epochs': 50}
# Epoch 1/50 - Train Loss: 0.1346, Train Corr: 0.9075
# Epoch 1/50 - Val Loss: 0.0582, Val Corr: 0.9405, Pearson Corr: 0.3925
# Epoch 2/50 - Train Loss: 0.0264, Train Corr: 0.9698
# Epoch 2/50 - Val Loss: 0.0598, Val Corr: 0.9375, Pearson Corr: 0.4397
# Epoch 3/50 - Train Loss: 0.0112, Train Corr: 0.9870
# Epoch 3/50 - Val Loss: 0.0644, Val Corr: 0.9323, Pearson Corr: 0.3840
# Epoch 4/50 - Train Loss: 0.0071, Train Corr: 0.9919
# Epoch 4/50 - Val Loss: 0.0625, Val Corr: 0.9343, Pearson Corr: 0.4173
# Epoch 5/50 - Train Loss: 0.0054, Train Corr: 0.9940
# Epoch 5/50 - Val Loss: 0.0597, Val Corr: 0.9391, Pearson Corr: 0.3521
# Epoch 6/50 - Train Loss: 0.0067, Train Corr: 0.9925
# Epoch 6/50 - Val Loss: 0.0617, Val Corr: 0.9349, Pearson Corr: 0.4577
# Epoch 7/50 - Train Loss: 0.0038, Train Corr: 0.9958
# Epoch 7/50 - Val Loss: 0.0610, Val Corr: 0.9352, Pearson Corr: 0.4764
# Epoch 8/50 - Train Loss: 0.0032, Train Corr: 0.9965
# Epoch 8/50 - Val Loss: 0.0599, Val Corr: 0.9374, Pearson Corr: 0.4421
# Epoch 9/50 - Train Loss: 0.0029, Train Corr: 0.9969
# Epoch 9/50 - Val Loss: 0.0648, Val Corr: 0.9310, Pearson Corr: 0.4221
# Epoch 10/50 - Train Loss: 0.0028, Train Corr: 0.9969
# Epoch 10/50 - Val Loss: 0.0619, Val Corr: 0.9346, Pearson Corr: 0.4418
# Epoch 11/50 - Train Loss: 0.0024, Train Corr: 0.9975
# Epoch 11/50 - Val Loss: 0.0621, Val Corr: 0.9338, Pearson Corr: 0.4587
# Epoch 12/50 - Train Loss: 0.0043, Train Corr: 0.9952
# Epoch 12/50 - Val Loss: 0.0950, Val Corr: 0.8986, Pearson Corr: 0.1031
# Epoch 13/50 - Train Loss: 0.0033, Train Corr: 0.9964
# Epoch 13/50 - Val Loss: 0.0934, Val Corr: 0.9021, Pearson Corr: 0.0943
# Epoch 14/50 - Train Loss: 0.0022, Train Corr: 0.9977
# Epoch 14/50 - Val Loss: 0.1004, Val Corr: 0.8916, Pearson Corr: 0.1159
# Epoch 15/50 - Train Loss: 0.0019, Train Corr: 0.9980
# Epoch 15/50 - Val Loss: 0.1014, Val Corr: 0.8913, Pearson Corr: 0.1066
# Epoch 16/50 - Train Loss: 0.0018, Train Corr: 0.9981
# Epoch 16/50 - Val Loss: 0.0975, Val Corr: 0.8960, Pearson Corr: 0.1291
# Epoch 17/50 - Train Loss: 0.0018, Train Corr: 0.9981
# Epoch 17/50 - Val Loss: 0.0966, Val Corr: 0.8980, Pearson Corr: 0.1030
# Epoch 18/50 - Train Loss: 0.0016, Train Corr: 0.9984
# Epoch 18/50 - Val Loss: 0.0969, Val Corr: 0.8975, Pearson Corr: 0.1023
# Epoch 19/50 - Train Loss: 0.0028, Train Corr: 0.9970
# Epoch 19/50 - Val Loss: 0.0961, Val Corr: 0.8985, Pearson Corr: 0.0745
# Epoch 20/50 - Train Loss: 0.0019, Train Corr: 0.9980
# Epoch 20/50 - Val Loss: 0.0994, Val Corr: 0.8944, Pearson Corr: 0.0772
# Epoch 21/50 - Train Loss: 0.0014, Train Corr: 0.9985
# Epoch 21/50 - Val Loss: 0.0958, Val Corr: 0.8984, Pearson Corr: 0.0989
# Epoch 22/50 - Train Loss: 0.0014, Train Corr: 0.9986
# Epoch 22/50 - Val Loss: 0.0984, Val Corr: 0.8948, Pearson Corr: 0.0966
# Epoch 23/50 - Train Loss: 0.0013, Train Corr: 0.9986
# Epoch 23/50 - Val Loss: 0.0954, Val Corr: 0.8976, Pearson Corr: 0.1290
# Epoch 24/50 - Train Loss: 0.0012, Train Corr: 0.9987
# Epoch 24/50 - Val Loss: 0.0964, Val Corr: 0.8972, Pearson Corr: 0.1115
# Epoch 25/50 - Train Loss: 0.0012, Train Corr: 0.9987
# Epoch 25/50 - Val Loss: 0.1056, Val Corr: 0.8849, Pearson Corr: 0.1082
# Epoch 26/50 - Train Loss: 0.0012, Train Corr: 0.9988
# Epoch 26/50 - Val Loss: 0.0904, Val Corr: 0.9042, Pearson Corr: 0.1308
# Epoch 27/50 - Train Loss: 0.0011, Train Corr: 0.9988
# Epoch 27/50 - Val Loss: 0.0917, Val Corr: 0.9034, Pearson Corr: 0.1146
# Epoch 28/50 - Train Loss: 0.0011, Train Corr: 0.9988
# Epoch 28/50 - Val Loss: 0.0844, Val Corr: 0.9098, Pearson Corr: 0.1889
# Epoch 29/50 - Train Loss: 0.0039, Train Corr: 0.9955
# Epoch 29/50 - Val Loss: 0.0689, Val Corr: 0.9262, Pearson Corr: 0.3841
# Epoch 30/50 - Train Loss: 0.0016, Train Corr: 0.9983
# Epoch 30/50 - Val Loss: 0.0677, Val Corr: 0.9269, Pearson Corr: 0.4288
# Epoch 31/50 - Train Loss: 0.0012, Train Corr: 0.9987
# Epoch 31/50 - Val Loss: 0.0675, Val Corr: 0.9268, Pearson Corr: 0.4510
# Epoch 32/50 - Train Loss: 0.0011, Train Corr: 0.9989
# Epoch 32/50 - Val Loss: 0.0626, Val Corr: 0.9329, Pearson Corr: 0.4692
# Epoch 33/50 - Train Loss: 0.0010, Train Corr: 0.9989
# Epoch 33/50 - Val Loss: 0.0623, Val Corr: 0.9334, Pearson Corr: 0.4637
# Epoch 34/50 - Train Loss: 0.0010, Train Corr: 0.9989
# Epoch 34/50 - Val Loss: 0.0608, Val Corr: 0.9351, Pearson Corr: 0.4747
# Epoch 35/50 - Train Loss: 0.0010, Train Corr: 0.9989
# Epoch 35/50 - Val Loss: 0.1005, Val Corr: 0.8905, Pearson Corr: 0.1357
# Epoch 36/50 - Train Loss: 0.0009, Train Corr: 0.9990
# Epoch 36/50 - Val Loss: 0.0913, Val Corr: 0.9017, Pearson Corr: 0.1820
# Epoch 37/50 - Train Loss: 0.0009, Train Corr: 0.9991
# Epoch 37/50 - Val Loss: 0.0757, Val Corr: 0.9196, Pearson Corr: 0.2979
# Epoch 38/50 - Train Loss: 0.0008, Train Corr: 0.9992
# Epoch 38/50 - Val Loss: 0.0652, Val Corr: 0.9307, Pearson Corr: 0.4197
# Epoch 39/50 - Train Loss: 0.0008, Train Corr: 0.9991
# Epoch 39/50 - Val Loss: 0.0669, Val Corr: 0.9285, Pearson Corr: 0.4328
# Epoch 40/50 - Train Loss: 0.0024, Train Corr: 0.9975
# Epoch 40/50 - Val Loss: 0.0728, Val Corr: 0.9384, Pearson Corr: 0.1567
# Epoch 41/50 - Train Loss: 0.0195, Train Corr: 0.9797
# Epoch 41/50 - Val Loss: 0.0863, Val Corr: 0.9085, Pearson Corr: 0.1461
# Epoch 42/50 - Train Loss: 0.0051, Train Corr: 0.9943
# Epoch 42/50 - Val Loss: 0.0921, Val Corr: 0.9037, Pearson Corr: 0.0610
# Epoch 43/50 - Train Loss: 0.0036, Train Corr: 0.9961
# Epoch 43/50 - Val Loss: 0.0754, Val Corr: 0.9213, Pearson Corr: 0.2570
# Epoch 44/50 - Train Loss: 0.0027, Train Corr: 0.9971
# Epoch 44/50 - Val Loss: 0.0700, Val Corr: 0.9262, Pearson Corr: 0.3350
# Epoch 45/50 - Train Loss: 0.0022, Train Corr: 0.9976
# Epoch 45/50 - Val Loss: 0.0650, Val Corr: 0.9315, Pearson Corr: 0.3983
# Epoch 46/50 - Train Loss: 0.0021, Train Corr: 0.9978
# Epoch 46/50 - Val Loss: 0.0670, Val Corr: 0.9287, Pearson Corr: 0.3981
# Epoch 47/50 - Train Loss: 0.0018, Train Corr: 0.9980
# Epoch 47/50 - Val Loss: 0.0615, Val Corr: 0.9352, Pearson Corr: 0.4429
# Epoch 48/50 - Train Loss: 0.0017, Train Corr: 0.9982
# Epoch 48/50 - Val Loss: 0.0649, Val Corr: 0.9316, Pearson Corr: 0.4235
# Epoch 49/50 - Train Loss: 0.0015, Train Corr: 0.9984
# Epoch 49/50 - Val Loss: 0.0648, Val Corr: 0.9309, Pearson Corr: 0.4497
# Epoch 50/50 - Train Loss: 0.0020, Train Corr: 0.9978
# Epoch 50/50 - Val Loss: 0.0807, Val Corr: 0.9174, Pearson Corr: 0.1273
# Final Pearson score: 0.1414
#
# Testing hyperparams: {'lr': 0.01, 'alpha': 0.7, 'weight_decay': 0.001, 'num_epochs': 50}
# Epoch 1/50 - Train Loss: 0.1562, Train Corr: 0.9072
# Epoch 1/50 - Val Loss: 0.0503, Val Corr: 0.9486, Pearson Corr: 0.5291
# Epoch 2/50 - Train Loss: 0.0224, Train Corr: 0.9741
# Epoch 2/50 - Val Loss: 0.0530, Val Corr: 0.9459, Pearson Corr: 0.4984
# Epoch 3/50 - Train Loss: 0.0123, Train Corr: 0.9855
# Epoch 3/50 - Val Loss: 0.0573, Val Corr: 0.9409, Pearson Corr: 0.4692
# Epoch 4/50 - Train Loss: 0.0085, Train Corr: 0.9900
# Epoch 4/50 - Val Loss: 0.0574, Val Corr: 0.9402, Pearson Corr: 0.4990
# Epoch 5/50 - Train Loss: 0.0068, Train Corr: 0.9921
# Epoch 5/50 - Val Loss: 0.0554, Val Corr: 0.9423, Pearson Corr: 0.4995
# Epoch 6/50 - Train Loss: 0.0060, Train Corr: 0.9931
# Epoch 6/50 - Val Loss: 0.0588, Val Corr: 0.9384, Pearson Corr: 0.4846
# Epoch 7/50 - Train Loss: 0.0045, Train Corr: 0.9950
# Epoch 7/50 - Val Loss: 0.0597, Val Corr: 0.9373, Pearson Corr: 0.4913
# Epoch 8/50 - Train Loss: 0.0040, Train Corr: 0.9955
# Epoch 8/50 - Val Loss: 0.0555, Val Corr: 0.9417, Pearson Corr: 0.4987
# Epoch 9/50 - Train Loss: 0.0040, Train Corr: 0.9956
# Epoch 9/50 - Val Loss: 0.0565, Val Corr: 0.9411, Pearson Corr: 0.4840
# Epoch 10/50 - Train Loss: 0.0033, Train Corr: 0.9964
# Epoch 10/50 - Val Loss: 0.0590, Val Corr: 0.9380, Pearson Corr: 0.4868
# Epoch 11/50 - Train Loss: 0.0029, Train Corr: 0.9968
# Epoch 11/50 - Val Loss: 0.0577, Val Corr: 0.9398, Pearson Corr: 0.4973
# Epoch 12/50 - Train Loss: 0.0027, Train Corr: 0.9971
# Epoch 12/50 - Val Loss: 0.0587, Val Corr: 0.9383, Pearson Corr: 0.4635
# Epoch 13/50 - Train Loss: 0.0026, Train Corr: 0.9972
# Epoch 13/50 - Val Loss: 0.0572, Val Corr: 0.9399, Pearson Corr: 0.5013
# Epoch 14/50 - Train Loss: 0.0023, Train Corr: 0.9975
# Epoch 14/50 - Val Loss: 0.0562, Val Corr: 0.9408, Pearson Corr: 0.5104
# Epoch 15/50 - Train Loss: 0.0021, Train Corr: 0.9977
# Epoch 15/50 - Val Loss: 0.0571, Val Corr: 0.9401, Pearson Corr: 0.4924
# Epoch 16/50 - Train Loss: 0.0023, Train Corr: 0.9975
# Epoch 16/50 - Val Loss: 0.0528, Val Corr: 0.9446, Pearson Corr: 0.5138
# Epoch 17/50 - Train Loss: 0.0022, Train Corr: 0.9976
# Epoch 17/50 - Val Loss: 0.0564, Val Corr: 0.9403, Pearson Corr: 0.4977
# Epoch 18/50 - Train Loss: 0.0062, Train Corr: 0.9929
# Epoch 18/50 - Val Loss: 0.0564, Val Corr: 0.9423, Pearson Corr: 0.4443
# Epoch 19/50 - Train Loss: 0.0023, Train Corr: 0.9974
# Epoch 19/50 - Val Loss: 0.0554, Val Corr: 0.9434, Pearson Corr: 0.4614
# Epoch 20/50 - Train Loss: 0.0019, Train Corr: 0.9979
# Epoch 20/50 - Val Loss: 0.0572, Val Corr: 0.9407, Pearson Corr: 0.4808
# Epoch 21/50 - Train Loss: 0.0016, Train Corr: 0.9982
# Epoch 21/50 - Val Loss: 0.0548, Val Corr: 0.9433, Pearson Corr: 0.4955
# Epoch 22/50 - Train Loss: 0.0015, Train Corr: 0.9983
# Epoch 22/50 - Val Loss: 0.0540, Val Corr: 0.9436, Pearson Corr: 0.5166
# Epoch 23/50 - Train Loss: 0.0015, Train Corr: 0.9984
# Epoch 23/50 - Val Loss: 0.0581, Val Corr: 0.9388, Pearson Corr: 0.4977
# Epoch 24/50 - Train Loss: 0.0014, Train Corr: 0.9985
# Epoch 24/50 - Val Loss: 0.0566, Val Corr: 0.9412, Pearson Corr: 0.4896
# Epoch 25/50 - Train Loss: 0.0013, Train Corr: 0.9986
# Epoch 25/50 - Val Loss: 0.0559, Val Corr: 0.9422, Pearson Corr: 0.4757
# Epoch 26/50 - Train Loss: 0.0012, Train Corr: 0.9987
# Epoch 26/50 - Val Loss: 0.0574, Val Corr: 0.9401, Pearson Corr: 0.4888
# Epoch 27/50 - Train Loss: 0.0012, Train Corr: 0.9987
# Epoch 27/50 - Val Loss: 0.0593, Val Corr: 0.9375, Pearson Corr: 0.4854
# Epoch 28/50 - Train Loss: 0.0012, Train Corr: 0.9987
# Epoch 28/50 - Val Loss: 0.0548, Val Corr: 0.9430, Pearson Corr: 0.5037
# Epoch 29/50 - Train Loss: 0.0010, Train Corr: 0.9989
# Epoch 29/50 - Val Loss: 0.0553, Val Corr: 0.9420, Pearson Corr: 0.5280
# Epoch 30/50 - Train Loss: 0.0010, Train Corr: 0.9989
# Epoch 30/50 - Val Loss: 0.0565, Val Corr: 0.9406, Pearson Corr: 0.5136
# Epoch 31/50 - Train Loss: 0.0009, Train Corr: 0.9990
# Epoch 31/50 - Val Loss: 0.0584, Val Corr: 0.9380, Pearson Corr: 0.5141
# Epoch 32/50 - Train Loss: 0.0039, Train Corr: 0.9955
# Epoch 32/50 - Val Loss: 0.0527, Val Corr: 0.9473, Pearson Corr: 0.4703
# Epoch 33/50 - Train Loss: 0.0014, Train Corr: 0.9985
# Epoch 33/50 - Val Loss: 0.0538, Val Corr: 0.9434, Pearson Corr: 0.5285
# Epoch 34/50 - Train Loss: 0.0010, Train Corr: 0.9989
# Epoch 34/50 - Val Loss: 0.0538, Val Corr: 0.9430, Pearson Corr: 0.5357
# Epoch 35/50 - Train Loss: 0.0009, Train Corr: 0.9990
# Epoch 35/50 - Val Loss: 0.0546, Val Corr: 0.9422, Pearson Corr: 0.5359
# Epoch 36/50 - Train Loss: 0.0009, Train Corr: 0.9991
# Epoch 36/50 - Val Loss: 0.0567, Val Corr: 0.9399, Pearson Corr: 0.5081
# Epoch 37/50 - Train Loss: 0.0008, Train Corr: 0.9991
# Epoch 37/50 - Val Loss: 0.0579, Val Corr: 0.9386, Pearson Corr: 0.4976
# Epoch 38/50 - Train Loss: 0.0008, Train Corr: 0.9992
# Epoch 38/50 - Val Loss: 0.0559, Val Corr: 0.9409, Pearson Corr: 0.5278
# Epoch 39/50 - Train Loss: 0.0007, Train Corr: 0.9992
# Epoch 39/50 - Val Loss: 0.0562, Val Corr: 0.9406, Pearson Corr: 0.5123
# Epoch 40/50 - Train Loss: 0.0020, Train Corr: 0.9977
# Epoch 40/50 - Val Loss: 0.0620, Val Corr: 0.9409, Pearson Corr: 0.2542
# Epoch 41/50 - Train Loss: 0.0017, Train Corr: 0.9981
# Epoch 41/50 - Val Loss: 0.0570, Val Corr: 0.9397, Pearson Corr: 0.5102
# Epoch 42/50 - Train Loss: 0.0009, Train Corr: 0.9990
# Epoch 42/50 - Val Loss: 0.0553, Val Corr: 0.9414, Pearson Corr: 0.5306
# Epoch 43/50 - Train Loss: 0.0008, Train Corr: 0.9992
# Epoch 43/50 - Val Loss: 0.0555, Val Corr: 0.9410, Pearson Corr: 0.5299
# Epoch 44/50 - Train Loss: 0.0019, Train Corr: 0.9978
# Epoch 44/50 - Val Loss: 0.0659, Val Corr: 0.9439, Pearson Corr: 0.2922
# Epoch 45/50 - Train Loss: 0.0113, Train Corr: 0.9877
# Epoch 45/50 - Val Loss: 0.0569, Val Corr: 0.9437, Pearson Corr: 0.3708
# Epoch 46/50 - Train Loss: 0.0033, Train Corr: 0.9963
# Epoch 46/50 - Val Loss: 0.0531, Val Corr: 0.9451, Pearson Corr: 0.4866
# Epoch 47/50 - Train Loss: 0.0023, Train Corr: 0.9975
# Epoch 47/50 - Val Loss: 0.0569, Val Corr: 0.9401, Pearson Corr: 0.5156
# Epoch 48/50 - Train Loss: 0.0019, Train Corr: 0.9979
# Epoch 48/50 - Val Loss: 0.0563, Val Corr: 0.9402, Pearson Corr: 0.5221
# Epoch 49/50 - Train Loss: 0.0016, Train Corr: 0.9982
# Epoch 49/50 - Val Loss: 0.0567, Val Corr: 0.9395, Pearson Corr: 0.5268
# Epoch 50/50 - Train Loss: 0.0015, Train Corr: 0.9984
# Epoch 50/50 - Val Loss: 0.0545, Val Corr: 0.9420, Pearson Corr: 0.5431
# Final Pearson score: 0.5773
#
# Testing hyperparams: {'lr': 0.005, 'alpha': 0.3, 'weight_decay': 0.0001, 'num_epochs': 50}
# Epoch 1/50 - Train Loss: 0.0875, Train Corr: 0.8868
# Epoch 1/50 - Val Loss: 0.0252, Val Corr: 0.9431, Pearson Corr: 0.2081
# Epoch 2/50 - Train Loss: 0.0196, Train Corr: 0.9490
# Epoch 2/50 - Val Loss: 0.0241, Val Corr: 0.9433, Pearson Corr: 0.3697
# Epoch 3/50 - Train Loss: 0.0090, Train Corr: 0.9757
# Epoch 3/50 - Val Loss: 0.0222, Val Corr: 0.9465, Pearson Corr: 0.5335
# Epoch 4/50 - Train Loss: 0.0053, Train Corr: 0.9854
# Epoch 4/50 - Val Loss: 0.0221, Val Corr: 0.9460, Pearson Corr: 0.5536
# Epoch 5/50 - Train Loss: 0.0039, Train Corr: 0.9893
# Epoch 5/50 - Val Loss: 0.0227, Val Corr: 0.9476, Pearson Corr: 0.4067
# Epoch 6/50 - Train Loss: 0.0034, Train Corr: 0.9908
# Epoch 6/50 - Val Loss: 0.0227, Val Corr: 0.9465, Pearson Corr: 0.4474
# Epoch 7/50 - Train Loss: 0.0026, Train Corr: 0.9930
# Epoch 7/50 - Val Loss: 0.0226, Val Corr: 0.9456, Pearson Corr: 0.4912
# Epoch 8/50 - Train Loss: 0.0022, Train Corr: 0.9941
# Epoch 8/50 - Val Loss: 0.0222, Val Corr: 0.9472, Pearson Corr: 0.4748
# Epoch 9/50 - Train Loss: 0.0019, Train Corr: 0.9950
# Epoch 9/50 - Val Loss: 0.0234, Val Corr: 0.9426, Pearson Corr: 0.4903
# Epoch 10/50 - Train Loss: 0.0017, Train Corr: 0.9956
# Epoch 10/50 - Val Loss: 0.0223, Val Corr: 0.9455, Pearson Corr: 0.5221
# Epoch 11/50 - Train Loss: 0.0014, Train Corr: 0.9962
# Epoch 11/50 - Val Loss: 0.0246, Val Corr: 0.9391, Pearson Corr: 0.4863
# Epoch 12/50 - Train Loss: 0.0014, Train Corr: 0.9964
# Epoch 12/50 - Val Loss: 0.0235, Val Corr: 0.9422, Pearson Corr: 0.5191
# Epoch 13/50 - Train Loss: 0.0012, Train Corr: 0.9968
# Epoch 13/50 - Val Loss: 0.0234, Val Corr: 0.9428, Pearson Corr: 0.4923
# Epoch 14/50 - Train Loss: 0.0012, Train Corr: 0.9970
# Epoch 14/50 - Val Loss: 0.0240, Val Corr: 0.9411, Pearson Corr: 0.4955
# Epoch 15/50 - Train Loss: 0.0010, Train Corr: 0.9973
# Epoch 15/50 - Val Loss: 0.0245, Val Corr: 0.9397, Pearson Corr: 0.4865
# Epoch 16/50 - Train Loss: 0.0010, Train Corr: 0.9974
# Epoch 16/50 - Val Loss: 0.0247, Val Corr: 0.9390, Pearson Corr: 0.4853
# Epoch 17/50 - Train Loss: 0.0009, Train Corr: 0.9977
# Epoch 17/50 - Val Loss: 0.0241, Val Corr: 0.9405, Pearson Corr: 0.5026
# Epoch 18/50 - Train Loss: 0.0014, Train Corr: 0.9962
# Epoch 18/50 - Val Loss: 0.0247, Val Corr: 0.9385, Pearson Corr: 0.4962
# Epoch 19/50 - Train Loss: 0.0009, Train Corr: 0.9977
# Epoch 19/50 - Val Loss: 0.0249, Val Corr: 0.9384, Pearson Corr: 0.4749
# Epoch 20/50 - Train Loss: 0.0008, Train Corr: 0.9980
# Epoch 20/50 - Val Loss: 0.0243, Val Corr: 0.9390, Pearson Corr: 0.5207
# Epoch 21/50 - Train Loss: 0.0008, Train Corr: 0.9980
# Epoch 21/50 - Val Loss: 0.0236, Val Corr: 0.9409, Pearson Corr: 0.5391
# Epoch 22/50 - Train Loss: 0.0007, Train Corr: 0.9982
# Epoch 22/50 - Val Loss: 0.0243, Val Corr: 0.9393, Pearson Corr: 0.5194
# Epoch 23/50 - Train Loss: 0.0007, Train Corr: 0.9983
# Epoch 23/50 - Val Loss: 0.0247, Val Corr: 0.9386, Pearson Corr: 0.4991
# Epoch 24/50 - Train Loss: 0.0006, Train Corr: 0.9985
# Epoch 24/50 - Val Loss: 0.0245, Val Corr: 0.9391, Pearson Corr: 0.5045
# Epoch 25/50 - Train Loss: 0.0006, Train Corr: 0.9985
# Epoch 25/50 - Val Loss: 0.0248, Val Corr: 0.9381, Pearson Corr: 0.5106
# Epoch 26/50 - Train Loss: 0.0005, Train Corr: 0.9986
# Epoch 26/50 - Val Loss: 0.0242, Val Corr: 0.9400, Pearson Corr: 0.5033
# Epoch 27/50 - Train Loss: 0.0009, Train Corr: 0.9977
# Epoch 27/50 - Val Loss: 0.0244, Val Corr: 0.9400, Pearson Corr: 0.5016
# Epoch 28/50 - Train Loss: 0.0005, Train Corr: 0.9986
# Epoch 28/50 - Val Loss: 0.0245, Val Corr: 0.9389, Pearson Corr: 0.5148
# Epoch 29/50 - Train Loss: 0.0005, Train Corr: 0.9987
# Epoch 29/50 - Val Loss: 0.0230, Val Corr: 0.9437, Pearson Corr: 0.4987
# Epoch 30/50 - Train Loss: 0.0006, Train Corr: 0.9984
# Epoch 30/50 - Val Loss: 0.0241, Val Corr: 0.9403, Pearson Corr: 0.5200
# Epoch 31/50 - Train Loss: 0.0005, Train Corr: 0.9988
# Epoch 31/50 - Val Loss: 0.0249, Val Corr: 0.9380, Pearson Corr: 0.5051
# Epoch 32/50 - Train Loss: 0.0004, Train Corr: 0.9990
# Epoch 32/50 - Val Loss: 0.0249, Val Corr: 0.9381, Pearson Corr: 0.5011
# Epoch 33/50 - Train Loss: 0.0008, Train Corr: 0.9978
# Epoch 33/50 - Val Loss: 0.0241, Val Corr: 0.9399, Pearson Corr: 0.5266
# Epoch 34/50 - Train Loss: 0.0004, Train Corr: 0.9990
# Epoch 34/50 - Val Loss: 0.0241, Val Corr: 0.9400, Pearson Corr: 0.5286
# Epoch 35/50 - Train Loss: 0.0004, Train Corr: 0.9990
# Epoch 35/50 - Val Loss: 0.0245, Val Corr: 0.9392, Pearson Corr: 0.5116
# Epoch 36/50 - Train Loss: 0.0004, Train Corr: 0.9991
# Epoch 36/50 - Val Loss: 0.0243, Val Corr: 0.9394, Pearson Corr: 0.5227
# Epoch 37/50 - Train Loss: 0.0003, Train Corr: 0.9991
# Epoch 37/50 - Val Loss: 0.0245, Val Corr: 0.9388, Pearson Corr: 0.5224
# Epoch 38/50 - Train Loss: 0.0003, Train Corr: 0.9991
# Epoch 38/50 - Val Loss: 0.0246, Val Corr: 0.9387, Pearson Corr: 0.5267
# Epoch 39/50 - Train Loss: 0.0003, Train Corr: 0.9992
# Epoch 39/50 - Val Loss: 0.0242, Val Corr: 0.9398, Pearson Corr: 0.5269
# Epoch 40/50 - Train Loss: 0.0003, Train Corr: 0.9992
# Epoch 40/50 - Val Loss: 0.0244, Val Corr: 0.9393, Pearson Corr: 0.5145
# Epoch 41/50 - Train Loss: 0.0003, Train Corr: 0.9992
# Epoch 41/50 - Val Loss: 0.0254, Val Corr: 0.9374, Pearson Corr: 0.4842
# Epoch 42/50 - Train Loss: 0.0003, Train Corr: 0.9992
# Epoch 42/50 - Val Loss: 0.0240, Val Corr: 0.9404, Pearson Corr: 0.5273
# Epoch 43/50 - Train Loss: 0.0003, Train Corr: 0.9993
# Epoch 43/50 - Val Loss: 0.0243, Val Corr: 0.9393, Pearson Corr: 0.5353
# Epoch 44/50 - Train Loss: 0.0003, Train Corr: 0.9993
# Epoch 44/50 - Val Loss: 0.0242, Val Corr: 0.9394, Pearson Corr: 0.5352
# Epoch 45/50 - Train Loss: 0.0003, Train Corr: 0.9993
# Epoch 45/50 - Val Loss: 0.0239, Val Corr: 0.9405, Pearson Corr: 0.5333
# Epoch 46/50 - Train Loss: 0.0011, Train Corr: 0.9970
# Epoch 46/50 - Val Loss: 0.0212, Val Corr: 0.9493, Pearson Corr: 0.5067
# Epoch 47/50 - Train Loss: 0.0006, Train Corr: 0.9985
# Epoch 47/50 - Val Loss: 0.0228, Val Corr: 0.9439, Pearson Corr: 0.5427
# Epoch 48/50 - Train Loss: 0.0003, Train Corr: 0.9991
# Epoch 48/50 - Val Loss: 0.0229, Val Corr: 0.9432, Pearson Corr: 0.5562
# Epoch 49/50 - Train Loss: 0.0003, Train Corr: 0.9993
# Epoch 49/50 - Val Loss: 0.0237, Val Corr: 0.9412, Pearson Corr: 0.5399
# Epoch 50/50 - Train Loss: 0.0003, Train Corr: 0.9994
# Epoch 50/50 - Val Loss: 0.0231, Val Corr: 0.9427, Pearson Corr: 0.5598
# Final Pearson score: 0.5924
#
# Testing hyperparams: {'lr': 0.005, 'alpha': 0.3, 'weight_decay': 0.001, 'num_epochs': 50}
# Epoch 1/50 - Train Loss: 0.0963, Train Corr: 0.8786
# Epoch 1/50 - Val Loss: 0.0283, Val Corr: 0.9358, Pearson Corr: 0.0835
# Epoch 2/50 - Train Loss: 0.0168, Train Corr: 0.9557
# Epoch 2/50 - Val Loss: 0.0240, Val Corr: 0.9431, Pearson Corr: 0.4229
# Epoch 3/50 - Train Loss: 0.0076, Train Corr: 0.9792
# Epoch 3/50 - Val Loss: 0.0221, Val Corr: 0.9470, Pearson Corr: 0.5419
# Epoch 4/50 - Train Loss: 0.0050, Train Corr: 0.9863
# Epoch 4/50 - Val Loss: 0.0225, Val Corr: 0.9469, Pearson Corr: 0.5068
# Epoch 5/50 - Train Loss: 0.0038, Train Corr: 0.9896
# Epoch 5/50 - Val Loss: 0.0223, Val Corr: 0.9477, Pearson Corr: 0.5089
# Epoch 6/50 - Train Loss: 0.0029, Train Corr: 0.9920
# Epoch 6/50 - Val Loss: 0.0223, Val Corr: 0.9476, Pearson Corr: 0.5074
# Epoch 7/50 - Train Loss: 0.0025, Train Corr: 0.9932
# Epoch 7/50 - Val Loss: 0.0230, Val Corr: 0.9453, Pearson Corr: 0.5113
# Epoch 8/50 - Train Loss: 0.0022, Train Corr: 0.9942
# Epoch 8/50 - Val Loss: 0.0219, Val Corr: 0.9482, Pearson Corr: 0.5217
# Epoch 9/50 - Train Loss: 0.0019, Train Corr: 0.9950
# Epoch 9/50 - Val Loss: 0.0221, Val Corr: 0.9489, Pearson Corr: 0.4796
# Epoch 10/50 - Train Loss: 0.0017, Train Corr: 0.9956
# Epoch 10/50 - Val Loss: 0.0227, Val Corr: 0.9458, Pearson Corr: 0.5058
# Epoch 11/50 - Train Loss: 0.0015, Train Corr: 0.9961
# Epoch 11/50 - Val Loss: 0.0222, Val Corr: 0.9470, Pearson Corr: 0.5201
# Epoch 12/50 - Train Loss: 0.0014, Train Corr: 0.9963
# Epoch 12/50 - Val Loss: 0.0219, Val Corr: 0.9481, Pearson Corr: 0.5114
# Epoch 13/50 - Train Loss: 0.0013, Train Corr: 0.9966
# Epoch 13/50 - Val Loss: 0.0218, Val Corr: 0.9489, Pearson Corr: 0.4926
# Epoch 14/50 - Train Loss: 0.0014, Train Corr: 0.9965
# Epoch 14/50 - Val Loss: 0.0222, Val Corr: 0.9478, Pearson Corr: 0.4887
# Epoch 15/50 - Train Loss: 0.0010, Train Corr: 0.9973
# Epoch 15/50 - Val Loss: 0.0220, Val Corr: 0.9470, Pearson Corr: 0.5257
# Epoch 16/50 - Train Loss: 0.0010, Train Corr: 0.9974
# Epoch 16/50 - Val Loss: 0.0226, Val Corr: 0.9456, Pearson Corr: 0.5264
# Epoch 17/50 - Train Loss: 0.0009, Train Corr: 0.9977
# Epoch 17/50 - Val Loss: 0.0233, Val Corr: 0.9436, Pearson Corr: 0.5166
# Epoch 18/50 - Train Loss: 0.0009, Train Corr: 0.9978
# Epoch 18/50 - Val Loss: 0.0223, Val Corr: 0.9461, Pearson Corr: 0.5307
# Epoch 19/50 - Train Loss: 0.0009, Train Corr: 0.9976
# Epoch 19/50 - Val Loss: 0.0226, Val Corr: 0.9455, Pearson Corr: 0.5110
# Epoch 20/50 - Train Loss: 0.0018, Train Corr: 0.9953
# Epoch 20/50 - Val Loss: 0.0218, Val Corr: 0.9480, Pearson Corr: 0.5271
# Epoch 21/50 - Train Loss: 0.0008, Train Corr: 0.9979
# Epoch 21/50 - Val Loss: 0.0217, Val Corr: 0.9484, Pearson Corr: 0.5254
# Epoch 22/50 - Train Loss: 0.0007, Train Corr: 0.9981
# Epoch 22/50 - Val Loss: 0.0221, Val Corr: 0.9472, Pearson Corr: 0.5251
# Epoch 23/50 - Train Loss: 0.0007, Train Corr: 0.9982
# Epoch 23/50 - Val Loss: 0.0223, Val Corr: 0.9466, Pearson Corr: 0.5043
# Epoch 24/50 - Train Loss: 0.0006, Train Corr: 0.9984
# Epoch 24/50 - Val Loss: 0.0226, Val Corr: 0.9457, Pearson Corr: 0.5213
# Epoch 25/50 - Train Loss: 0.0006, Train Corr: 0.9984
# Epoch 25/50 - Val Loss: 0.0224, Val Corr: 0.9462, Pearson Corr: 0.5191
# Epoch 26/50 - Train Loss: 0.0006, Train Corr: 0.9984
# Epoch 26/50 - Val Loss: 0.0237, Val Corr: 0.9445, Pearson Corr: 0.4792
# Epoch 27/50 - Train Loss: 0.0007, Train Corr: 0.9983
# Epoch 27/50 - Val Loss: 0.0224, Val Corr: 0.9464, Pearson Corr: 0.5121
# Epoch 28/50 - Train Loss: 0.0006, Train Corr: 0.9986
# Epoch 28/50 - Val Loss: 0.0214, Val Corr: 0.9489, Pearson Corr: 0.5453
# Epoch 29/50 - Train Loss: 0.0005, Train Corr: 0.9987
# Epoch 29/50 - Val Loss: 0.0224, Val Corr: 0.9461, Pearson Corr: 0.5307
# Epoch 30/50 - Train Loss: 0.0005, Train Corr: 0.9987
# Epoch 30/50 - Val Loss: 0.0231, Val Corr: 0.9443, Pearson Corr: 0.5223
# Epoch 31/50 - Train Loss: 0.0005, Train Corr: 0.9988
# ...
# Epoch 25/50 - Train Loss: 0.0027, Train Corr: 0.9957
# Epoch 25/50 - Val Loss: 0.0419, Val Corr: 0.9382, Pearson Corr: 0.4850
# Epoch 26/50 - Train Loss: 0.0026, Train Corr: 0.9960
# Epoch 26/50 - Val Loss: 0.0419, Val Corr: 0.9380, Pearson Corr: 0.4879
# Epoch 27/50 - Train Loss: 0.0024, Train Corr: 0.9963
# Epoch 27/50 - Val Loss: 0.0419, Val Corr: 0.9379, Pearson Corr: 0.4901
# Epoch 28/50 - Train Loss: 0.0022, Train Corr: 0.9966
# Epoch 28/50 - Val Loss: 0.0424, Val Corr: 0.9371, Pearson Corr: 0.4821
# Epoch 29/50 - Train Loss: 0.0021, Train Corr: 0.9968
# Epoch 29/50 - Val Loss: 0.0414, Val Corr: 0.9388, Pearson Corr: 0.4804
# Epoch 30/50 - Train Loss: 0.0021, Train Corr: 0.9968
# Epoch 30/50 - Val Loss: 0.0413, Val Corr: 0.9389, Pearson Corr: 0.5007
# Epoch 31/50 - Train Loss: 0.0018, Train Corr: 0.9972
# Epoch 31/50 - Val Loss: 0.0417, Val Corr: 0.9383, Pearson Corr: 0.4953
# Epoch 32/50 - Train Loss: 0.0017, Train Corr: 0.9973
# Epoch 32/50 - Val Loss: 0.0409, Val Corr: 0.9399, Pearson Corr: 0.5047
# Epoch 33/50 - Train Loss: 0.0016, Train Corr: 0.9975
# Epoch 33/50 - Val Loss: 0.0429, Val Corr: 0.9362, Pearson Corr: 0.4847
# Epoch 34/50 - Train Loss: 0.0015, Train Corr: 0.9977
# Epoch 34/50 - Val Loss: 0.0427, Val Corr: 0.9367, Pearson Corr: 0.4949
# Epoch 35/50 - Train Loss: 0.0014, Train Corr: 0.9978
# Epoch 35/50 - Val Loss: 0.0412, Val Corr: 0.9389, Pearson Corr: 0.5123
# Epoch 36/50 - Train Loss: 0.0014, Train Corr: 0.9979
# Epoch 36/50 - Val Loss: 0.0423, Val Corr: 0.9373, Pearson Corr: 0.4998
# Epoch 37/50 - Train Loss: 0.0013, Train Corr: 0.9980
# Epoch 37/50 - Val Loss: 0.0428, Val Corr: 0.9366, Pearson Corr: 0.4905
# Epoch 38/50 - Train Loss: 0.0012, Train Corr: 0.9982
# Epoch 38/50 - Val Loss: 0.0418, Val Corr: 0.9380, Pearson Corr: 0.4988
# Epoch 39/50 - Train Loss: 0.0011, Train Corr: 0.9983
# Epoch 39/50 - Val Loss: 0.0424, Val Corr: 0.9367, Pearson Corr: 0.5033
# Epoch 40/50 - Train Loss: 0.0011, Train Corr: 0.9983
# Epoch 40/50 - Val Loss: 0.0411, Val Corr: 0.9392, Pearson Corr: 0.5065
# Epoch 41/50 - Train Loss: 0.0011, Train Corr: 0.9984
# Epoch 41/50 - Val Loss: 0.0418, Val Corr: 0.9380, Pearson Corr: 0.5007
# Epoch 42/50 - Train Loss: 0.0010, Train Corr: 0.9985
# Epoch 42/50 - Val Loss: 0.0424, Val Corr: 0.9370, Pearson Corr: 0.4976
# Epoch 43/50 - Train Loss: 0.0012, Train Corr: 0.9982
# Epoch 43/50 - Val Loss: 0.0425, Val Corr: 0.9368, Pearson Corr: 0.4983
# Epoch 44/50 - Train Loss: 0.0009, Train Corr: 0.9986
# Epoch 44/50 - Val Loss: 0.0419, Val Corr: 0.9378, Pearson Corr: 0.5057
# Epoch 45/50 - Train Loss: 0.0009, Train Corr: 0.9987
# Epoch 45/50 - Val Loss: 0.0416, Val Corr: 0.9383, Pearson Corr: 0.5077
# Epoch 46/50 - Train Loss: 0.0008, Train Corr: 0.9987
# Epoch 46/50 - Val Loss: 0.0409, Val Corr: 0.9393, Pearson Corr: 0.5120
# Epoch 47/50 - Train Loss: 0.0008, Train Corr: 0.9988
# Epoch 47/50 - Val Loss: 0.0418, Val Corr: 0.9377, Pearson Corr: 0.5145
# Epoch 48/50 - Train Loss: 0.0008, Train Corr: 0.9987
# Epoch 48/50 - Val Loss: 0.0426, Val Corr: 0.9366, Pearson Corr: 0.5001
# Epoch 49/50 - Train Loss: 0.0007, Train Corr: 0.9988
# Epoch 49/50 - Val Loss: 0.0417, Val Corr: 0.9379, Pearson Corr: 0.5126
# Epoch 50/50 - Train Loss: 0.0008, Train Corr: 0.9988
# Epoch 50/50 - Val Loss: 0.0426, Val Corr: 0.9359, Pearson Corr: 0.5074
# Final Pearson score: 0.5511
#
# Testing hyperparams: {'lr': 0.001, 'alpha': 0.7, 'weight_decay': 0.0001, 'num_epochs': 50}
# Epoch 1/50 - Train Loss: 0.7237, Train Corr: 0.7326
# Epoch 1/50 - Val Loss: 0.0643, Val Corr: 0.9405, Pearson Corr: 0.0850
# Epoch 2/50 - Train Loss: 0.1318, Train Corr: 0.8810
# Epoch 2/50 - Val Loss: 0.0626, Val Corr: 0.9416, Pearson Corr: 0.0738
# Epoch 3/50 - Train Loss: 0.0943, Train Corr: 0.9047
# Epoch 3/50 - Val Loss: 0.0609, Val Corr: 0.9426, Pearson Corr: 0.1093
# Epoch 4/50 - Train Loss: 0.0769, Train Corr: 0.9193
# Epoch 4/50 - Val Loss: 0.0582, Val Corr: 0.9439, Pearson Corr: 0.1597
# Epoch 5/50 - Train Loss: 0.0645, Train Corr: 0.9317
# Epoch 5/50 - Val Loss: 0.0573, Val Corr: 0.9443, Pearson Corr: 0.2514
# Epoch 6/50 - Train Loss: 0.0534, Train Corr: 0.9426
# Epoch 6/50 - Val Loss: 0.0535, Val Corr: 0.9466, Pearson Corr: 0.4097
# Epoch 7/50 - Train Loss: 0.0420, Train Corr: 0.9543
# Epoch 7/50 - Val Loss: 0.0530, Val Corr: 0.9460, Pearson Corr: 0.4581
# Epoch 8/50 - Train Loss: 0.0338, Train Corr: 0.9628
# Epoch 8/50 - Val Loss: 0.0551, Val Corr: 0.9440, Pearson Corr: 0.4228
# Epoch 9/50 - Train Loss: 0.0269, Train Corr: 0.9698
# Epoch 9/50 - Val Loss: 0.0542, Val Corr: 0.9448, Pearson Corr: 0.4658
# Epoch 10/50 - Train Loss: 0.0221, Train Corr: 0.9748
# Epoch 10/50 - Val Loss: 0.0592, Val Corr: 0.9417, Pearson Corr: 0.3823
# Epoch 11/50 - Train Loss: 0.0185, Train Corr: 0.9788
# Epoch 11/50 - Val Loss: 0.0565, Val Corr: 0.9426, Pearson Corr: 0.4575
# Epoch 12/50 - Train Loss: 0.0157, Train Corr: 0.9820
# Epoch 12/50 - Val Loss: 0.0568, Val Corr: 0.9432, Pearson Corr: 0.4485
# Epoch 13/50 - Train Loss: 0.0134, Train Corr: 0.9846
# Epoch 13/50 - Val Loss: 0.0585, Val Corr: 0.9426, Pearson Corr: 0.3976
# Epoch 14/50 - Train Loss: 0.0119, Train Corr: 0.9864
# Epoch 14/50 - Val Loss: 0.0563, Val Corr: 0.9436, Pearson Corr: 0.4637
# Epoch 15/50 - Train Loss: 0.0108, Train Corr: 0.9876
# Epoch 15/50 - Val Loss: 0.0571, Val Corr: 0.9418, Pearson Corr: 0.4505
# Epoch 16/50 - Train Loss: 0.0094, Train Corr: 0.9893
# Epoch 16/50 - Val Loss: 0.0549, Val Corr: 0.9445, Pearson Corr: 0.4620
# Epoch 17/50 - Train Loss: 0.0090, Train Corr: 0.9897
# Epoch 17/50 - Val Loss: 0.0579, Val Corr: 0.9417, Pearson Corr: 0.4197
# Epoch 18/50 - Train Loss: 0.0078, Train Corr: 0.9911
# Epoch 18/50 - Val Loss: 0.0539, Val Corr: 0.9455, Pearson Corr: 0.4744
# Epoch 19/50 - Train Loss: 0.0079, Train Corr: 0.9910
# Epoch 19/50 - Val Loss: 0.0557, Val Corr: 0.9432, Pearson Corr: 0.4764
# Epoch 20/50 - Train Loss: 0.0067, Train Corr: 0.9925
# Epoch 20/50 - Val Loss: 0.0554, Val Corr: 0.9435, Pearson Corr: 0.4702
# Epoch 21/50 - Train Loss: 0.0062, Train Corr: 0.9930
# Epoch 21/50 - Val Loss: 0.0568, Val Corr: 0.9418, Pearson Corr: 0.4649
# Epoch 22/50 - Train Loss: 0.0076, Train Corr: 0.9915
# Epoch 22/50 - Val Loss: 0.0582, Val Corr: 0.9399, Pearson Corr: 0.4605
# Epoch 23/50 - Train Loss: 0.0059, Train Corr: 0.9933
# Epoch 23/50 - Val Loss: 0.0576, Val Corr: 0.9407, Pearson Corr: 0.4651
# Epoch 24/50 - Train Loss: 0.0052, Train Corr: 0.9942
# Epoch 24/50 - Val Loss: 0.0551, Val Corr: 0.9429, Pearson Corr: 0.5002
# Epoch 25/50 - Train Loss: 0.0046, Train Corr: 0.9948
# Epoch 25/50 - Val Loss: 0.0549, Val Corr: 0.9429, Pearson Corr: 0.5125
# Epoch 26/50 - Train Loss: 0.0044, Train Corr: 0.9951
# Epoch 26/50 - Val Loss: 0.0545, Val Corr: 0.9435, Pearson Corr: 0.5097
# Epoch 27/50 - Train Loss: 0.0053, Train Corr: 0.9941
# Epoch 27/50 - Val Loss: 0.0542, Val Corr: 0.9436, Pearson Corr: 0.5110
# Epoch 28/50 - Train Loss: 0.0041, Train Corr: 0.9955
# Epoch 28/50 - Val Loss: 0.0543, Val Corr: 0.9434, Pearson Corr: 0.5196
# Epoch 29/50 - Train Loss: 0.0036, Train Corr: 0.9960
# Epoch 29/50 - Val Loss: 0.0565, Val Corr: 0.9406, Pearson Corr: 0.5062
# Epoch 30/50 - Train Loss: 0.0035, Train Corr: 0.9962
# Epoch 30/50 - Val Loss: 0.0555, Val Corr: 0.9416, Pearson Corr: 0.5287
# Epoch 31/50 - Train Loss: 0.0033, Train Corr: 0.9964
# Epoch 31/50 - Val Loss: 0.0563, Val Corr: 0.9406, Pearson Corr: 0.5222
# Epoch 32/50 - Train Loss: 0.0031, Train Corr: 0.9966
# Epoch 32/50 - Val Loss: 0.0554, Val Corr: 0.9421, Pearson Corr: 0.5177
# Epoch 33/50 - Train Loss: 0.0032, Train Corr: 0.9965
# Epoch 33/50 - Val Loss: 0.0552, Val Corr: 0.9420, Pearson Corr: 0.5209
# Epoch 34/50 - Train Loss: 0.0029, Train Corr: 0.9968
# Epoch 34/50 - Val Loss: 0.0553, Val Corr: 0.9420, Pearson Corr: 0.5201
# Epoch 35/50 - Train Loss: 0.0052, Train Corr: 0.9943
# Epoch 35/50 - Val Loss: 0.0561, Val Corr: 0.9412, Pearson Corr: 0.5136
# Epoch 36/50 - Train Loss: 0.0032, Train Corr: 0.9965
# Epoch 36/50 - Val Loss: 0.0558, Val Corr: 0.9413, Pearson Corr: 0.5131
# Epoch 37/50 - Train Loss: 0.0027, Train Corr: 0.9970
# Epoch 37/50 - Val Loss: 0.0555, Val Corr: 0.9413, Pearson Corr: 0.5308
# Epoch 38/50 - Train Loss: 0.0025, Train Corr: 0.9973
# Epoch 38/50 - Val Loss: 0.0550, Val Corr: 0.9414, Pearson Corr: 0.5460
# Epoch 39/50 - Train Loss: 0.0027, Train Corr: 0.9971
# Epoch 39/50 - Val Loss: 0.0553, Val Corr: 0.9414, Pearson Corr: 0.5364
# Epoch 40/50 - Train Loss: 0.0022, Train Corr: 0.9976
# Epoch 40/50 - Val Loss: 0.0545, Val Corr: 0.9425, Pearson Corr: 0.5371
# Epoch 41/50 - Train Loss: 0.0022, Train Corr: 0.9976
# Epoch 41/50 - Val Loss: 0.0562, Val Corr: 0.9404, Pearson Corr: 0.5284
# Epoch 42/50 - Train Loss: 0.0021, Train Corr: 0.9977
# Epoch 42/50 - Val Loss: 0.0561, Val Corr: 0.9406, Pearson Corr: 0.5259
# Epoch 43/50 - Train Loss: 0.0020, Train Corr: 0.9978
# Epoch 43/50 - Val Loss: 0.0554, Val Corr: 0.9415, Pearson Corr: 0.5312
# Epoch 44/50 - Train Loss: 0.0018, Train Corr: 0.9980
# Epoch 44/50 - Val Loss: 0.0562, Val Corr: 0.9406, Pearson Corr: 0.5229
# Epoch 45/50 - Train Loss: 0.0019, Train Corr: 0.9980
# Epoch 45/50 - Val Loss: 0.0562, Val Corr: 0.9406, Pearson Corr: 0.5214
# Epoch 46/50 - Train Loss: 0.0018, Train Corr: 0.9980
# Epoch 46/50 - Val Loss: 0.0542, Val Corr: 0.9431, Pearson Corr: 0.5320
# Epoch 47/50 - Train Loss: 0.0018, Train Corr: 0.9981
# Epoch 47/50 - Val Loss: 0.0574, Val Corr: 0.9391, Pearson Corr: 0.5142
# Epoch 48/50 - Train Loss: 0.0016, Train Corr: 0.9983
# Epoch 48/50 - Val Loss: 0.0565, Val Corr: 0.9401, Pearson Corr: 0.5253
# Epoch 49/50 - Train Loss: 0.0016, Train Corr: 0.9982
# Epoch 49/50 - Val Loss: 0.0554, Val Corr: 0.9413, Pearson Corr: 0.5302
# Epoch 50/50 - Train Loss: 0.0015, Train Corr: 0.9984
# Epoch 50/50 - Val Loss: 0.0561, Val Corr: 0.9406, Pearson Corr: 0.5317
# Final Pearson score: 0.5610
#
# Testing hyperparams: {'lr': 0.001, 'alpha': 0.7, 'weight_decay': 0.001, 'num_epochs': 50}
# Epoch 1/50 - Train Loss: 0.8280, Train Corr: 0.7604
# Epoch 1/50 - Val Loss: 0.0643, Val Corr: 0.9392, Pearson Corr: -0.0067
# Epoch 2/50 - Train Loss: 0.1575, Train Corr: 0.8851
# Epoch 2/50 - Val Loss: 0.0616, Val Corr: 0.9412, Pearson Corr: -0.0309
# Epoch 3/50 - Train Loss: 0.1071, Train Corr: 0.9050
# Epoch 3/50 - Val Loss: 0.0623, Val Corr: 0.9409, Pearson Corr: -0.0601
# Epoch 4/50 - Train Loss: 0.0799, Train Corr: 0.9230
# Epoch 4/50 - Val Loss: 0.0625, Val Corr: 0.9403, Pearson Corr: 0.0124
# Epoch 5/50 - Train Loss: 0.0635, Train Corr: 0.9356
# Epoch 5/50 - Val Loss: 0.0677, Val Corr: 0.9361, Pearson Corr: -0.0665
# Epoch 6/50 - Train Loss: 0.0502, Train Corr: 0.9475
# Epoch 6/50 - Val Loss: 0.0654, Val Corr: 0.9397, Pearson Corr: -0.0368
# Epoch 7/50 - Train Loss: 0.0376, Train Corr: 0.9598
# Epoch 7/50 - Val Loss: 0.0780, Val Corr: 0.9236, Pearson Corr: -0.0280
# Epoch 8/50 - Train Loss: 0.0283, Train Corr: 0.9689
# Epoch 8/50 - Val Loss: 0.1075, Val Corr: 0.8819, Pearson Corr: -0.0342
# Epoch 9/50 - Train Loss: 0.0222, Train Corr: 0.9751
# Epoch 9/50 - Val Loss: 0.1126, Val Corr: 0.8757, Pearson Corr: 0.0570
# Epoch 10/50 - Train Loss: 0.0182, Train Corr: 0.9794
# Epoch 10/50 - Val Loss: 0.1116, Val Corr: 0.8760, Pearson Corr: 0.1486
# Epoch 11/50 - Train Loss: 0.0152, Train Corr: 0.9826
# Epoch 11/50 - Val Loss: 0.1044, Val Corr: 0.8847, Pearson Corr: 0.1835
# Epoch 12/50 - Train Loss: 0.0129, Train Corr: 0.9852
# Epoch 12/50 - Val Loss: 0.0948, Val Corr: 0.8989, Pearson Corr: 0.1799
# Epoch 13/50 - Train Loss: 0.0111, Train Corr: 0.9872
# Epoch 13/50 - Val Loss: 0.1027, Val Corr: 0.8899, Pearson Corr: 0.1060
# Epoch 14/50 - Train Loss: 0.0097, Train Corr: 0.9888
# Epoch 14/50 - Val Loss: 0.0786, Val Corr: 0.9192, Pearson Corr: 0.2476
# Epoch 15/50 - Train Loss: 0.0086, Train Corr: 0.9900
# Epoch 15/50 - Val Loss: 0.0694, Val Corr: 0.9304, Pearson Corr: 0.3000
# Epoch 16/50 - Train Loss: 0.0076, Train Corr: 0.9912
# Epoch 16/50 - Val Loss: 0.0718, Val Corr: 0.9266, Pearson Corr: 0.3039
# Epoch 17/50 - Train Loss: 0.0070, Train Corr: 0.9920
# Epoch 17/50 - Val Loss: 0.0726, Val Corr: 0.9288, Pearson Corr: 0.2152
# Epoch 18/50 - Train Loss: 0.0062, Train Corr: 0.9929
# Epoch 18/50 - Val Loss: 0.0684, Val Corr: 0.9312, Pearson Corr: 0.3129
# Epoch 19/50 - Train Loss: 0.0057, Train Corr: 0.9934
# Epoch 19/50 - Val Loss: 0.0680, Val Corr: 0.9327, Pearson Corr: 0.2666
# Epoch 20/50 - Train Loss: 0.0052, Train Corr: 0.9941
# Epoch 20/50 - Val Loss: 0.0626, Val Corr: 0.9364, Pearson Corr: 0.3853
# Epoch 21/50 - Train Loss: 0.0047, Train Corr: 0.9946
# Epoch 21/50 - Val Loss: 0.0645, Val Corr: 0.9352, Pearson Corr: 0.3379
# Epoch 22/50 - Train Loss: 0.0043, Train Corr: 0.9951
# Epoch 22/50 - Val Loss: 0.0631, Val Corr: 0.9361, Pearson Corr: 0.3680
# Epoch 23/50 - Train Loss: 0.0041, Train Corr: 0.9953
# Epoch 23/50 - Val Loss: 0.0626, Val Corr: 0.9373, Pearson Corr: 0.3393
# Epoch 24/50 - Train Loss: 0.0037, Train Corr: 0.9958
# Epoch 24/50 - Val Loss: 0.0595, Val Corr: 0.9392, Pearson Corr: 0.4213
# Epoch 25/50 - Train Loss: 0.0035, Train Corr: 0.9961
# Epoch 25/50 - Val Loss: 0.0643, Val Corr: 0.9364, Pearson Corr: 0.3007
# Epoch 26/50 - Train Loss: 0.0033, Train Corr: 0.9963
# Epoch 26/50 - Val Loss: 0.0606, Val Corr: 0.9389, Pearson Corr: 0.3743
# Epoch 27/50 - Train Loss: 0.0029, Train Corr: 0.9967
# Epoch 27/50 - Val Loss: 0.0614, Val Corr: 0.9387, Pearson Corr: 0.3533
# Epoch 28/50 - Train Loss: 0.0028, Train Corr: 0.9969
# Epoch 28/50 - Val Loss: 0.0635, Val Corr: 0.9358, Pearson Corr: 0.3543
# Epoch 29/50 - Train Loss: 0.0026, Train Corr: 0.9971
# Epoch 29/50 - Val Loss: 0.0628, Val Corr: 0.9349, Pearson Corr: 0.4126
# Epoch 30/50 - Train Loss: 0.0025, Train Corr: 0.9972
# Epoch 30/50 - Val Loss: 0.0592, Val Corr: 0.9385, Pearson Corr: 0.4592
# Epoch 31/50 - Train Loss: 0.0023, Train Corr: 0.9975
# Epoch 31/50 - Val Loss: 0.0605, Val Corr: 0.9388, Pearson Corr: 0.3846
# Epoch 32/50 - Train Loss: 0.0022, Train Corr: 0.9976
# Epoch 32/50 - Val Loss: 0.0605, Val Corr: 0.9365, Pearson Corr: 0.4665
# Epoch 33/50 - Train Loss: 0.0021, Train Corr: 0.9977
# Epoch 33/50 - Val Loss: 0.0631, Val Corr: 0.9377, Pearson Corr: 0.3120
# Epoch 34/50 - Train Loss: 0.0020, Train Corr: 0.9978
# Epoch 34/50 - Val Loss: 0.0580, Val Corr: 0.9389, Pearson Corr: 0.4819
# Epoch 35/50 - Train Loss: 0.0018, Train Corr: 0.9980
# Epoch 35/50 - Val Loss: 0.0597, Val Corr: 0.9379, Pearson Corr: 0.4481
# Epoch 36/50 - Train Loss: 0.0019, Train Corr: 0.9979
# Epoch 36/50 - Val Loss: 0.0597, Val Corr: 0.9378, Pearson Corr: 0.4565
# Epoch 37/50 - Train Loss: 0.0016, Train Corr: 0.9982
# Epoch 37/50 - Val Loss: 0.0610, Val Corr: 0.9377, Pearson Corr: 0.4118
# Epoch 38/50 - Train Loss: 0.0015, Train Corr: 0.9983
# Epoch 38/50 - Val Loss: 0.0590, Val Corr: 0.9380, Pearson Corr: 0.4826
# Epoch 39/50 - Train Loss: 0.0015, Train Corr: 0.9983
# Epoch 39/50 - Val Loss: 0.0593, Val Corr: 0.9385, Pearson Corr: 0.4423
# Epoch 40/50 - Train Loss: 0.0017, Train Corr: 0.9981
# Epoch 40/50 - Val Loss: 0.0586, Val Corr: 0.9384, Pearson Corr: 0.4822
# Epoch 41/50 - Train Loss: 0.0014, Train Corr: 0.9985
# Epoch 41/50 - Val Loss: 0.0588, Val Corr: 0.9386, Pearson Corr: 0.4605
# Epoch 42/50 - Train Loss: 0.0013, Train Corr: 0.9986
# Epoch 42/50 - Val Loss: 0.0593, Val Corr: 0.9374, Pearson Corr: 0.4834
# Epoch 43/50 - Train Loss: 0.0012, Train Corr: 0.9987
# Epoch 43/50 - Val Loss: 0.0579, Val Corr: 0.9387, Pearson Corr: 0.5099
# Epoch 44/50 - Train Loss: 0.0012, Train Corr: 0.9987
# Epoch 44/50 - Val Loss: 0.0575, Val Corr: 0.9389, Pearson Corr: 0.5226
# Epoch 45/50 - Train Loss: 0.0011, Train Corr: 0.9987
# Epoch 45/50 - Val Loss: 0.0570, Val Corr: 0.9398, Pearson Corr: 0.5154
# Epoch 46/50 - Train Loss: 0.0011, Train Corr: 0.9988
# Epoch 46/50 - Val Loss: 0.0574, Val Corr: 0.9390, Pearson Corr: 0.5223
# Epoch 47/50 - Train Loss: 0.0010, Train Corr: 0.9989
# Epoch 47/50 - Val Loss: 0.0574, Val Corr: 0.9391, Pearson Corr: 0.5195
# Epoch 48/50 - Train Loss: 0.0010, Train Corr: 0.9989
# Epoch 48/50 - Val Loss: 0.0572, Val Corr: 0.9393, Pearson Corr: 0.5202
# Epoch 49/50 - Train Loss: 0.0014, Train Corr: 0.9984
# Epoch 49/50 - Val Loss: 0.0566, Val Corr: 0.9402, Pearson Corr: 0.5226
# Epoch 50/50 - Train Loss: 0.0010, Train Corr: 0.9989
# Epoch 50/50 - Val Loss: 0.0560, Val Corr: 0.9410, Pearson Corr: 0.5238
# Final Pearson score: 0.5484
#
# Best hyperparameters: {'lr': 0.005, 'alpha': 0.3, 'weight_decay': 0.0001, 'num_epochs': 50}
# Best Pearson score: 0.5924

# %%
# model = EncoderDecoder(input_channels=CHANNELS_NUM * WAVELET_NUM, output_channels=5)

# %%
# model = train(model, train_loader, val_loader, num_epochs=50)

# %%
def plot_fingerwise_timeseries(actuals, predictions, time_axis, finger_labels):
    """
    Plot actual vs. predicted ECoG signals for each finger as separate time series subplots.
    
    Parameters:
    - actuals: numpy array of shape (timesteps, num_fingers)
    - predictions: numpy array of shape (timesteps, num_fingers)
    - time_axis: numpy array of shape (timesteps,), optional
    - finger_labels: list of string labels for fingers
    """
    num_fingers = actuals.shape[1]

    plt.figure(figsize=(12, 8))

    for i in range(num_fingers):
        plt.subplot(num_fingers, 1, i+1)
        plt.plot(time_axis, actuals[:, i], label='True' if i == 0 else "", color='blue', alpha=0.7)
        plt.plot(time_axis, predictions[:, i], label='Prediction' if i == 0 else "", color='green', alpha=0.7)

        plt.ylabel(finger_labels[i])
        
        plt.grid(True)
        
        if i == 0:
            plt.legend()

        if i == num_fingers - 1:
            plt.xlabel("Time (s)")

    plt.suptitle("Actual vs Predicted ECoG Time Series for Each Finger")
    plt.tight_layout()
    plt.show()

# %%
actuals, predictions = test_model(best_model, val_loader)
print(actuals.shape, predictions.shape)
# Out:
# (19724, 5, 256) (19724, 5, 256)

# %%
# Print pearon correlation (SotA model 0.67)
final_pearson = pearson_correlation_metric(torch.tensor(predictions), torch.tensor(actuals)).item()
print("Final Pearson Correlation: ", final_pearson)
torch.save(best_model.state_dict(), f"{final_pearson}.pth")
# Out:
# Final Pearson Correlation:  0.5924338698387146

# %%
model = EncoderDecoder(input_channels=CHANNELS_NUM * WAVELET_NUM, output_channels=5)
model.load_state_dict(torch.load(f"{final_pearson}.pth"))

actuals, predictions = test_model(model, val_loader)
final_pearson = pearson_correlation_metric(torch.tensor(predictions), torch.tensor(actuals)).item()
print("Final Pearson Correlation: ", final_pearson)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model = EncoderDecoder(input_channels=CHANNELS_NUM * WAVELET_NUM, output_channels=5)
#       2 model.load_state_dict(torch.load(f"{final_pearson}.pth"))
#       4 actuals, predictions = test_model(model, val_loader)
#
# NameError: name 'EncoderDecoder' is not defined

# %%
# Plot the actual and predicted ECoG signals for each finger
finger_labels = ['Thumb', 'Index', 'Middle', 'Ring', 'Little']
time_axis = np.arange(actuals.shape[0]) / SAMPLE_RATE # Time axis in seconds
plot_fingerwise_timeseries(actuals, predictions, time_axis=time_axis, finger_labels=finger_labels)
# Out:
# C:\Users\nutri\AppData\Local\Temp\ipykernel_22832\1445647410.py:31: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# C:\Users\nutri\AppData\Local\Temp\ipykernel_22832\1445647410.py:31: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
# d:\Downloads\project\.venv\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
